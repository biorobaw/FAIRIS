# %%
import pickle
import os
import gc
import numpy as np
from sklearn.cluster import KMeans, Birch
from scipy.spatial.distance import cdist
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.metrics import calinski_harabasz_score
from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
import math
from sklearn.metrics import homogeneity_score
from scipy.stats import entropy
from scipy.spatial import ConvexHull
from matplotlib.patches import Ellipse
from sklearn.cluster import DBSCAN
import random
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from scipy.spatial.distance import pdist, squareform
from scipy.stats import pearsonr
import seaborn as sns
from sklearn.cluster import KMeans
from collections import defaultdict
from matplotlib.animation import FuncAnimation
from scipy.stats import kruskal
from scipy.stats import f_oneway, kruskal
from fairis_tools.experiment_tools.place_cell.PlaceCellLibrary import *

# %%
os.chdir("../../..")
print(os.getcwd())
# Out:
# /Users/titonka/FAIRIS

# %%
with open("data/VisualPlaceCellData/LM8_Testing", 'rb') as file:
    test_data = pickle.load(file)

landmarks = [
    (1.85, 1.85, (1.00, 0.00, 0.00)),
    (0.00, 2.61, (0.00, 1.00, 0.00)),
    (-1.85, 1.85, (0.00, 0.00, 1.00)),
    (-2.61, 0.00, (1.00, 1.00, 0.00)),
    (-2.61, 0.00, (1.00, 0.00, 1.00)),
    (-1.85, -1.85, (0.00, 1.00, 1.00)),
    (0.00, -2.61, (1.00, 0.50, 0.00)),
    (1.85, -1.85, (0.50, 0.00, 0.50)),
    (2.61, 0.00, (0.50, 0.50, 0.00))
]

# %%
def group_dataset_by_theta(dataset):
    """
    Groups observations in the dataset by unique theta values. This function
    does not consider spatial proximity (x, y coordinates) during grouping.

    Parameters:
    - dataset: An object with an 'observations' attribute, which is a list of observations.
               Each observation is expected to have a 'theta' attribute.

    Returns:
    - dict: A dictionary where the keys are unique theta values, and the values are
            lists of observations corresponding to each theta.
    """
    # Initialize a dictionary to store the grouped observations by theta
    theta_groups = defaultdict(list)

    # Iterate through the observations and group them by their theta value
    for observation in dataset.observations:
        theta_groups[observation.theta].append(observation)

    return theta_groups


def select_knn_with_orientation(grouped_data, orientation, k, mode='nearest_same_orientation'):
    """
    Selects k data points based on spatial proximity and orientation.

    Parameters:
    - grouped_data: dict, output of group_dataset_by_theta function {theta: [data_points]}.
    - orientation: float, the orientation (theta) to select the initial data point from.
    - k: int, the number of neighbors to select.
    - mode: str, selection mode ('nearest_same_orientation', 'farthest_same_orientation',
             'farthest_different_orientation', 'nearest_different_orientation').

    Returns:
    - list: A list containing k selected data points based on the chosen mode.
    """
    if mode not in ['nearest_same_orientation', 'farthest_same_orientation',
                    'farthest_different_orientation', 'nearest_different_orientation']:
        raise ValueError("Invalid mode. Choose from 'nearest_same_orientation', 'farthest_same_orientation', "
                         "'farthest_different_orientation', or 'nearest_different_orientation'.")

    if mode == 'nearest_same_orientation':
        # Get all points with the same orientation
        if orientation not in grouped_data or len(grouped_data[orientation]) == 0:
            raise ValueError(f"No data points available for the specified orientation: {orientation}")

        data_points = grouped_data[orientation]

        # Randomly select an initial data point
        selected_point = random.choice(data_points)
        selected_point_coords = np.array([selected_point.x, selected_point.y])

        # Find the k nearest neighbors
        distances = cdist([selected_point_coords], [(dp.x, dp.y) for dp in data_points])[0]
        nearest_indices = np.argsort(distances)[:k + 1]  # +1 to include the selected point

        # Return the initial point and k nearest neighbors
        return [data_points[i] for i in nearest_indices if data_points[i] != selected_point][:k]

    if mode == 'nearest_different_orientation':
        # Get all points with different orientations
        candidate_points = [dp for theta, points in grouped_data.items() if theta != orientation for dp in points]
        if len(candidate_points) == 0:
            raise ValueError("No data points available with different orientations.")

        # Randomly select an initial data point
        selected_point = random.choice(candidate_points)
        selected_point_coords = np.array([selected_point.x, selected_point.y])

        # Compute distances to all candidates
        distances = cdist([selected_point_coords], [(dp.x, dp.y) for dp in candidate_points])[0]
        nearest_indices = np.argsort(distances)[:k]  # Select k nearest neighbors

        return [candidate_points[i] for i in nearest_indices]

    if mode in ['farthest_same_orientation', 'farthest_different_orientation']:
        if mode == 'farthest_same_orientation':
            if orientation not in grouped_data or len(grouped_data[orientation]) == 0:
                raise ValueError(f"No data points available for the specified orientation: {orientation}")
            candidate_points = grouped_data[orientation]
        else:
            # Different orientation points
            candidate_points = [dp for theta, points in grouped_data.items() if theta != orientation for dp in points]
            if len(candidate_points) == 0:
                raise ValueError("No data points available with different orientations.")

        # Step 3: Convert points to (x, y) coordinates
        candidate_coords = np.array([(dp.x, dp.y) for dp in candidate_points])

        # Step 4: Greedy selection of k points that maximize pairwise distances
        # Randomly select the first point
        selected_indices = [random.randint(0, len(candidate_coords) - 1)]
        selected_points = [candidate_points[selected_indices[0]]]

        while len(selected_indices) < k:
            # Calculate distances from the current set of selected points to all candidates
            distances_to_selected = np.min(cdist(candidate_coords, candidate_coords[selected_indices]), axis=1)

            # Exclude already selected points
            distances_to_selected[selected_indices] = -np.inf

            # Select the point with the maximum distance to the current selection
            next_index = np.argmax(distances_to_selected)
            selected_indices.append(next_index)
            selected_points.append(candidate_points[next_index])

        return selected_points

def calculate_similarity_metrics(grouped_data, pc_network, n=20, mode='nearest_same_orientation',
                                 feature_type='multimodal'):
    """
    Calculate similarity metrics by repeatedly grouping data points using the specified mode.

    Parameters:
    - grouped_data: dict, output of group_dataset_by_theta function {theta: [data_points]}.
    - pc_network: object, the place cell network used to get activations.
    - n: int, number of times to perform grouping and calculate similarity metrics (default 20).
    - mode: str, selection mode ('nearest_same_orientation', 'farthest_same_orientation', or 'farthest_different_orientation').
    - feature_type: str, feature type used to calculate activations ('cnn' or 'multimodal').

    Returns:
    - DataFrame: A dataset of cosine similarity, Pearson correlation, and Euclidean distance for each iteration.
    - dict: The average values of each similarity metric across all iterations.
    """
    results = []

    for i in range(n):
        # Step 1: Select a group of data points using the specified mode
        selected_points = select_knn_with_orientation(grouped_data,
                                                      orientation=random.choice(list(grouped_data.keys())), k=5,
                                                      mode=mode)

        # Step 2: Compute place cell activations for each selected point
        activation_vectors = []
        for dp in selected_points:
            if feature_type == 'cnn':
                activations = pc_network.get_all_pc_activations_normalized(dp.cnn_feature_vector, norm_type='min_max')
            else:
                activations = pc_network.get_all_pc_activations_normalized(dp.multimodal_feature_vector,
                                                                           norm_type='min_max')
            activation_vectors.append(activations)

        activation_vectors = np.array(activation_vectors)

        # Step 3: Calculate similarity metrics
        cosine_sim_matrix = 1 - squareform(pdist(activation_vectors, metric='cosine'))
        euclidean_dist_matrix = squareform(pdist(activation_vectors, metric='euclidean'))
        n_place_cells = len(pc_network.pc_list)
        euclidean_scale = np.sqrt(n_place_cells)

        # Pearson correlation matrix
        num_vectors = len(activation_vectors)
        pearson_corr_matrix = np.zeros((num_vectors, num_vectors))
        for j in range(num_vectors):
            for k in range(num_vectors):
                if j != k:
                    pearson_corr, _ = pearsonr(activation_vectors[j], activation_vectors[k])
                    pearson_corr_matrix[j, k] = pearson_corr
                else:
                    pearson_corr_matrix[j, k] = 1  # Correlation with itself

        # Step 4: Calculate average metrics for the current iteration
        avg_cosine_sim = np.mean(cosine_sim_matrix[np.triu_indices(num_vectors, k=1)])
        avg_pearson_corr = np.mean(pearson_corr_matrix[np.triu_indices(num_vectors, k=1)])
        avg_euclidean_dist = np.mean(euclidean_dist_matrix[np.triu_indices(num_vectors, k=1)])

        # Store the results
        results.append({
            'Iteration': i + 1,
            'Avg Cosine Similarity': avg_cosine_sim,
            'Avg Pearson Correlation': avg_pearson_corr,
            'Avg Euclidean Distance': avg_euclidean_dist
        })

    # Convert results to a DataFrame
    results_df = pd.DataFrame(results)

    # Calculate overall averages
    averages = {
        'Average Cosine Similarity': results_df['Avg Cosine Similarity'].mean(),
        'Average Pearson Correlation': results_df['Avg Pearson Correlation'].mean(),
        'Average Euclidean Distance': results_df['Avg Euclidean Distance'].mean()
    }

    return results_df, averages


def analyze_similarity_across_modes(grouped_data, pc_network, n=20, feature_type='multimodal'):
    """
    Perform similarity analysis across different grouping modes, calculate averages,
    and test for significant differences between the modes using raw samples.

    Parameters:
    - grouped_data: dict, output of group_dataset_by_theta function {theta: [data_points]}.
    - pc_network: object, the place cell network used to get activations.
    - n: int, number of iterations for each mode (default 20).
    - feature_type: str, feature type used to calculate activations ('cnn' or 'multimodal').

    Returns:
    - None, but prints the summary of averages and statistical test findings.
    """

    # Modes to analyze
    modes = ['nearest_same_orientation', 'farthest_same_orientation',
             'farthest_different_orientation', 'nearest_different_orientation']

    # Store raw DataFrames for statistical testing
    combined_df_list = []

    for mode in modes:
        # Calculate similarity metrics for the given mode
        results_df, averages = calculate_similarity_metrics(grouped_data, pc_network, n=n, mode=mode,
                                                            feature_type=feature_type)

        # Add the mode as a column to the results DataFrame
        results_df['Mode'] = mode
        combined_df_list.append(results_df)

        # Print averages for this mode
        print(f"\nAverages for {mode}:")
        for metric, avg in averages.items():
            print(f"  {metric}: {avg:.4f}")

    # Combine all the results into a single DataFrame
    combined_df = pd.concat(combined_df_list, ignore_index=True)

    # Step 2: Perform ANOVA using raw results
    print("\n\n=== ANOVA Tests ===")
    metrics = ['Avg Cosine Similarity', 'Avg Pearson Correlation', 'Avg Euclidean Distance']

    for metric in metrics:
        # Perform ANOVA on the raw results
        f_stat, p_value = f_oneway(combined_df[combined_df['Mode'] == 'nearest_same_orientation'][metric],
                                   combined_df[combined_df['Mode'] == 'nearest_different_orientation'][metric],
                                   combined_df[combined_df['Mode'] == 'farthest_same_orientation'][metric],
                                   combined_df[combined_df['Mode'] == 'farthest_different_orientation'][metric])
        print(f"\nANOVA for {metric}: F-statistic = {f_stat:.4f}, p-value = {p_value:.4f}")

        if p_value < 0.05:
            print(f"  Significant difference found in {metric} across modes (p < 0.05)")
        else:
            print(f"  No significant difference in {metric} (p = {p_value:.4f})")

    # Step 3: Perform Kruskal-Wallis test as a backup
    print("\n=== Backup Kruskal-Wallis Tests ===")
    for metric in metrics:
        stat, p_value = kruskal(combined_df[combined_df['Mode'] == 'nearest_same_orientation'][metric],
                                combined_df[combined_df['Mode'] == 'nearest_different_orientation'][metric],
                                combined_df[combined_df['Mode'] == 'farthest_same_orientation'][metric],
                                combined_df[combined_df['Mode'] == 'farthest_different_orientation'][metric])
        print(f"Kruskal-Wallis test for {metric}: Statistic = {stat:.4f}, p-value = {p_value:.4f}")

# %%
feature_modes = ['multimodal']
num_pc = [10,20,100,500]
for feature_mode in feature_modes:
    for n in num_pc:
        print("===================================================================================================")
        print("Feature Type: ", feature_mode, "Number of PC: ", n)
        print("===================================================================================================")
        file_name = feature_mode+'_kmeans_'+str(n)+'centers'
        with open("data/VisualPlaceCellData/VisualPlaceCellClusters/"+file_name,'rb') as file:
            data = pickle.load(file)

        pc_network = VisualPlaceCellNetwork()
        for cluster in data:
            if cluster[1] != 0:
                pc_network.add_pc_to_network(cluster[0],radius=cluster[1])
            else:
                pc_network.add_pc_to_network(cluster[0],radius=1)
        del data
        out1 = gc.collect()

        # Group the data by Theta
        grouped_data = group_dataset_by_theta(test_data)
        analyze_similarity_across_modes(grouped_data, pc_network, n=n, feature_type=feature_mode)
# Out:
# ===================================================================================================
# Feature Type:  multimodal Number of PC:  10
# ===================================================================================================
# /Users/titonka/FAIRIS/fairis_venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/titonka/FAIRIS/fairis_venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 23
#      21 # Group the data by Theta
#      22 grouped_data = group_dataset_by_theta(test_data)
# ---> 23 analyze_similarity_across_modes(grouped_data, pc_network, n=n, feature_type=feature_mode)
#
# Cell In[8], line 207, in analyze_similarity_across_modes(grouped_data, pc_network, n, feature_type)
#     203 combined_df_list = []
#     205 for mode in modes:
#     206     # Calculate similarity metrics for the given mode
# --> 207     results_df, averages = calculate_similarity_metrics(grouped_data, pc_network, n=n, mode=mode, feature_type=feature_type)
#     209     # Add the mode as a column to the results DataFrame
#     210     results_df['Mode'] = mode
#
# Cell In[8], line 143, in calculate_similarity_metrics(grouped_data, pc_network, n, mode, feature_type)
#     140 activation_vectors = np.array(activation_vectors)
#     142 # Step 3: Calculate similarity metrics
# --> 143 cosine_sim_matrix = 1 - squareform(pdist(activation_vectors, metric='cosine'))
#     144 euclidean_dist_matrix = squareform(pdist(activation_vectors, metric='euclidean'))
#     145 n_place_cells = len(pc_network.pc_list)
#
# File ~/FAIRIS/fairis_venv/lib/python3.11/site-packages/scipy/spatial/distance.py:2161, in pdist(X, metric, out, **kwargs)
#    2159 s = X.shape
#    2160 if len(s) != 2:
# -> 2161     raise ValueError('A 2-dimensional array must be passed.')
#    2163 m, n = s
#    2165 if callable(metric):
#
# ValueError: A 2-dimensional array must be passed.

# %%
feature_modes = ['cnn']
num_pc = [10,20,100,500]
for feature_mode in feature_modes:
    for n in num_pc:
        print("===================================================================================================")
        print("Feature Type: ", feature_mode, "Number of PC: ", n)
        print("===================================================================================================")
        file_name = feature_mode+'_kmeans_'+str(n)+'centers'
        with open("data/VisualPlaceCellData/VisualPlaceCellClusters/"+file_name,'rb') as file:
            data = pickle.load(file)

        pc_network = VisualPlaceCellNetwork()
        for cluster in data:
            if cluster[1] != 0:
                pc_network.add_pc_to_network(cluster[0],radius=cluster[1])
            else:
                pc_network.add_pc_to_network(cluster[0],radius=1)
        del data
        out1 = gc.collect()

        # Group the data by Theta
        grouped_data = group_dataset_by_theta(test_data)
        analyze_similarity_across_modes(grouped_data, pc_network, n=n, feature_type=feature_mode)
# Out:
# ===================================================================================================
# Feature Type:  cnn Number of PC:  10
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9426
#   Average Pearson Correlation: 0.8236
#   Average Euclidean Distance: 0.5522
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.7692
#   Average Pearson Correlation: 0.2875
#   Average Euclidean Distance: 1.1225
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.7736
#   Average Pearson Correlation: 0.3719
#   Average Euclidean Distance: 1.0598
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.7902
#   Average Pearson Correlation: 0.3616
#   Average Euclidean Distance: 1.0326
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 23.4892, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 26.0270, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 23.8800, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 20.7761, p-value = 0.0001
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 22.1883, p-value = 0.0001
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 20.7732, p-value = 0.0001
# ===================================================================================================
# Feature Type:  cnn Number of PC:  20
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9669
#   Average Pearson Correlation: 0.8844
#   Average Euclidean Distance: 0.5973
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.8682
#   Average Pearson Correlation: 0.5004
#   Average Euclidean Distance: 1.2588
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8706
#   Average Pearson Correlation: 0.5221
#   Average Euclidean Distance: 1.2670
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9027
#   Average Pearson Correlation: 0.6299
#   Average Euclidean Distance: 1.0616
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 52.2862, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 51.5741, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 78.9783, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 49.4044, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 48.6694, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 49.4707, p-value = 0.0000
# ===================================================================================================
# Feature Type:  cnn Number of PC:  100
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9950
#   Average Pearson Correlation: 0.9466
#   Average Euclidean Distance: 0.6671
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.9817
#   Average Pearson Correlation: 0.7963
#   Average Euclidean Distance: 1.3322
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.9827
#   Average Pearson Correlation: 0.8060
#   Average Euclidean Distance: 1.3191
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9862
#   Average Pearson Correlation: 0.8493
#   Average Euclidean Distance: 1.1330
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 152.2090, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 171.5309, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 182.5629, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 207.9090, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 216.8603, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 211.2083, p-value = 0.0000
# ===================================================================================================
# Feature Type:  cnn Number of PC:  500
# ===================================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 23
#      21 # Group the data by Theta
#      22 grouped_data = group_dataset_by_theta(test_data)
# ---> 23 analyze_similarity_across_modes(grouped_data, pc_network, n=n, feature_type=feature_mode)
#
# Cell In[5], line 213, in analyze_similarity_across_modes(grouped_data, pc_network, n, feature_type)
#     209 combined_df_list = []
#     211 for mode in modes:
#     212     # Calculate similarity metrics for the given mode
# --> 213     results_df, averages = calculate_similarity_metrics(grouped_data, pc_network, n=n, mode=mode,
#     214                                                         feature_type=feature_type)
#     216     # Add the mode as a column to the results DataFrame
#     217     results_df['Mode'] = mode
#
# Cell In[5], line 138, in calculate_similarity_metrics(grouped_data, pc_network, n, mode, feature_type)
#     136 for dp in selected_points:
#     137     if feature_type == 'cnn':
# --> 138         activations = pc_network.get_all_pc_activations_normalized(dp.cnn_feature_vector, norm_type='min_max')
#     139     else:
#     140         activations = pc_network.get_all_pc_activations_normalized(dp.multimodal_feature_vector,
#     141                                                                    norm_type='min_max')
#
# File ~/FAIRIS/fairis_tools/experiment_tools/place_cell/PlaceCellLibrary.py:157, in VisualPlaceCellNetwork.get_all_pc_activations_normalized(self, robot_point, norm_type)
#     156 def get_all_pc_activations_normalized(self, robot_point,norm_type = 'norm'):
# --> 157     self.activate_pc_network(robot_point)
#     158     if norm_type == 'norm':
#     159         self.normilize_all_pc()
#
# File ~/FAIRIS/fairis_tools/experiment_tools/place_cell/PlaceCellLibrary.py:148, in VisualPlaceCellNetwork.activate_pc_network(self, robot_point)
#     145 def activate_pc_network(self, robot_point):
#     146     # Standard approach
#     147     for pc in self.pc_list:
# --> 148         pc.calculate_activation(robot_point)
#     149     self.normilize_all_pc()
#
# File ~/FAIRIS/fairis_tools/experiment_tools/place_cell/PlaceCellLibrary.py:121, in VisiualPlaceCell.calculate_activation(self, robot_point)
#     120 def calculate_activation(self,robot_point):
# --> 121     distance = np.linalg.norm(self.center_point - robot_point)
#     122     self.activity = np.exp(-(distance**2) / (2*self.sigma**2))
#
# File ~/FAIRIS/fairis_venv/lib/python3.11/site-packages/numpy/linalg/linalg.py:2379, in _norm_dispatcher(x, ord, axis, keepdims)
#    2375     result = op(svd(y, compute_uv=False), axis=-1)
#    2376     return result
# -> 2379 def _norm_dispatcher(x, ord=None, axis=None, keepdims=None):
#    2380     return (x,)
#    2383 @array_function_dispatch(_norm_dispatcher)
#    2384 def norm(x, ord=None, axis=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
feature_modes = ['multimodal','cnn']
num_pc = [10,20,100]
mazes = ['LM4','LM6']
for maze in mazes:
    with open("data/VisualPlaceCellData/"+maze+"Testing", 'rb') as file:
        test_data = pickle.load(file)
    for feature_mode in feature_modes:
        for n in num_pc:
            print("===================================================================================================")
            print("Maze: ",maze," Feature Type: ", feature_mode, " Number of PC: ", n)
            print("===================================================================================================")
            file_name = feature_mode+'_kmeans_'+str(n)+'centers'
            with open("data/VisualPlaceCellData/VisualPlaceCellClusters/"+file_name,'rb') as file:
                data = pickle.load(file)
    
            pc_network = VisualPlaceCellNetwork()
            for cluster in data:
                if cluster[1] != 0:
                    pc_network.add_pc_to_network(cluster[0],radius=cluster[1])
                else:
                    pc_network.add_pc_to_network(cluster[0],radius=1)
            del data
            out1 = gc.collect()
    
            # Group the data by Theta
            grouped_data = group_dataset_by_theta(test_data)
            analyze_similarity_across_modes(grouped_data, pc_network, n=n, feature_type=feature_mode)
# Out:
# ===================================================================================================
# Maze:  LM4  Feature Type:  multimodal  Number of PC:  10
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9487
#   Average Pearson Correlation: 0.7746
#   Average Euclidean Distance: 0.4975
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.7028
#   Average Pearson Correlation: 0.0526
#   Average Euclidean Distance: 1.3158
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.7735
#   Average Pearson Correlation: 0.1970
#   Average Euclidean Distance: 1.2284
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.8149
#   Average Pearson Correlation: 0.3192
#   Average Euclidean Distance: 1.0463
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 14.0969, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 17.6283, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 21.3745, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 21.3937, p-value = 0.0001
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 22.0141, p-value = 0.0001
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 22.4034, p-value = 0.0001
# ===================================================================================================
# Maze:  LM4  Feature Type:  multimodal  Number of PC:  20
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9627
#   Average Pearson Correlation: 0.7925
#   Average Euclidean Distance: 0.6415
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.8604
#   Average Pearson Correlation: 0.3250
#   Average Euclidean Distance: 1.3828
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8692
#   Average Pearson Correlation: 0.3363
#   Average Euclidean Distance: 1.3448
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9229
#   Average Pearson Correlation: 0.5635
#   Average Euclidean Distance: 1.0322
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 19.0364, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 30.4413, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 33.2309, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 36.0354, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 42.9369, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 44.3446, p-value = 0.0000
# ===================================================================================================
# Maze:  LM4  Feature Type:  multimodal  Number of PC:  100
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9443
#   Average Pearson Correlation: 0.7407
#   Average Euclidean Distance: 1.4190
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.7746
#   Average Pearson Correlation: 0.2160
#   Average Euclidean Distance: 2.8905
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8139
#   Average Pearson Correlation: 0.2867
#   Average Euclidean Distance: 2.7022
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.8475
#   Average Pearson Correlation: 0.3890
#   Average Euclidean Distance: 2.3904
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 96.0098, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 164.6238, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 183.7389, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 193.1307, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 203.5506, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 217.8016, p-value = 0.0000
# ===================================================================================================
# Maze:  LM4  Feature Type:  cnn  Number of PC:  10
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9282
#   Average Pearson Correlation: 0.7908
#   Average Euclidean Distance: 0.5864
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.7768
#   Average Pearson Correlation: 0.3396
#   Average Euclidean Distance: 1.0927
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.7919
#   Average Pearson Correlation: 0.3993
#   Average Euclidean Distance: 1.0298
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.8607
#   Average Pearson Correlation: 0.6220
#   Average Euclidean Distance: 0.8144
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 13.3136, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 16.7783, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 17.8600, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 21.1127, p-value = 0.0001
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 22.9976, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 24.7537, p-value = 0.0000
# ===================================================================================================
# Maze:  LM4  Feature Type:  cnn  Number of PC:  20
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9636
#   Average Pearson Correlation: 0.8687
#   Average Euclidean Distance: 0.6189
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.8657
#   Average Pearson Correlation: 0.5065
#   Average Euclidean Distance: 1.2785
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8628
#   Average Pearson Correlation: 0.4867
#   Average Euclidean Distance: 1.3072
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9139
#   Average Pearson Correlation: 0.6752
#   Average Euclidean Distance: 1.0149
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 62.7254, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 52.7548, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 78.4223, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 56.7296, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 54.4713, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 58.9930, p-value = 0.0000
# ===================================================================================================
# Maze:  LM4  Feature Type:  cnn  Number of PC:  100
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9951
#   Average Pearson Correlation: 0.9479
#   Average Euclidean Distance: 0.6755
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.9822
#   Average Pearson Correlation: 0.8020
#   Average Euclidean Distance: 1.3183
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.9832
#   Average Pearson Correlation: 0.8148
#   Average Euclidean Distance: 1.2735
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9878
#   Average Pearson Correlation: 0.8709
#   Average Euclidean Distance: 1.0757
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 141.7673, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 176.1941, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 166.1391, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 211.5330, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 228.7315, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 207.9560, p-value = 0.0000
# ===================================================================================================
# Maze:  LM6  Feature Type:  multimodal  Number of PC:  10
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9396
#   Average Pearson Correlation: 0.7593
#   Average Euclidean Distance: 0.5658
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.7451
#   Average Pearson Correlation: 0.1632
#   Average Euclidean Distance: 1.2205
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8100
#   Average Pearson Correlation: 0.3229
#   Average Euclidean Distance: 1.0938
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.8393
#   Average Pearson Correlation: 0.3968
#   Average Euclidean Distance: 0.9842
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 7.7278, p-value = 0.0004
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 11.0427, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 11.2127, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 14.9151, p-value = 0.0019
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 17.4351, p-value = 0.0006
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 16.8673, p-value = 0.0008
# ===================================================================================================
# Maze:  LM6  Feature Type:  multimodal  Number of PC:  20
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9663
#   Average Pearson Correlation: 0.7964
#   Average Euclidean Distance: 0.6125
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.8262
#   Average Pearson Correlation: 0.1819
#   Average Euclidean Distance: 1.5554
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8781
#   Average Pearson Correlation: 0.3795
#   Average Euclidean Distance: 1.2806
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9009
#   Average Pearson Correlation: 0.4714
#   Average Euclidean Distance: 1.1249
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 25.9730, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 38.7675, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 48.3226, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 42.4412, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 47.7117, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 52.1703, p-value = 0.0000
# ===================================================================================================
# Maze:  LM6  Feature Type:  multimodal  Number of PC:  100
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9337
#   Average Pearson Correlation: 0.7050
#   Average Euclidean Distance: 1.5640
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.7816
#   Average Pearson Correlation: 0.2391
#   Average Euclidean Distance: 2.8496
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.7958
#   Average Pearson Correlation: 0.2575
#   Average Euclidean Distance: 2.7811
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.8426
#   Average Pearson Correlation: 0.3572
#   Average Euclidean Distance: 2.4438
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 79.0356, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 148.7846, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 153.4303, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 174.9235, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 191.7434, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 203.5094, p-value = 0.0000
# ===================================================================================================
# Maze:  LM6  Feature Type:  cnn  Number of PC:  10
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9440
#   Average Pearson Correlation: 0.8339
#   Average Euclidean Distance: 0.5709
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.7468
#   Average Pearson Correlation: 0.2595
#   Average Euclidean Distance: 1.1654
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8012
#   Average Pearson Correlation: 0.4063
#   Average Euclidean Distance: 1.0246
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.8275
#   Average Pearson Correlation: 0.4958
#   Average Euclidean Distance: 0.9443
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 38.9480, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 44.0139, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 32.1981, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 27.6205, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 27.8298, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 26.9927, p-value = 0.0000
# ===================================================================================================
# Maze:  LM6  Feature Type:  cnn  Number of PC:  20
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9545
#   Average Pearson Correlation: 0.8317
#   Average Euclidean Distance: 0.6738
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.8599
#   Average Pearson Correlation: 0.4897
#   Average Euclidean Distance: 1.2897
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.8593
#   Average Pearson Correlation: 0.4774
#   Average Euclidean Distance: 1.2819
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9131
#   Average Pearson Correlation: 0.6685
#   Average Euclidean Distance: 1.0135
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 53.0885, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 42.7736, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 44.4217, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 52.8440, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 47.8074, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 48.4593, p-value = 0.0000
# ===================================================================================================
# Maze:  LM6  Feature Type:  cnn  Number of PC:  100
# ===================================================================================================
#
# Averages for nearest_same_orientation:
#   Average Cosine Similarity: 0.9948
#   Average Pearson Correlation: 0.9455
#   Average Euclidean Distance: 0.6803
#
# Averages for farthest_same_orientation:
#   Average Cosine Similarity: 0.9823
#   Average Pearson Correlation: 0.8029
#   Average Euclidean Distance: 1.2829
#
# Averages for farthest_different_orientation:
#   Average Cosine Similarity: 0.9834
#   Average Pearson Correlation: 0.8151
#   Average Euclidean Distance: 1.2826
#
# Averages for nearest_different_orientation:
#   Average Cosine Similarity: 0.9871
#   Average Pearson Correlation: 0.8602
#   Average Euclidean Distance: 1.0974
#
#
# === ANOVA Tests ===
#
# ANOVA for Avg Cosine Similarity: F-statistic = 131.7491, p-value = 0.0000
#   Significant difference found in Avg Cosine Similarity across modes (p < 0.05)
#
# ANOVA for Avg Pearson Correlation: F-statistic = 152.8971, p-value = 0.0000
#   Significant difference found in Avg Pearson Correlation across modes (p < 0.05)
#
# ANOVA for Avg Euclidean Distance: F-statistic = 162.9592, p-value = 0.0000
#   Significant difference found in Avg Euclidean Distance across modes (p < 0.05)
#
# === Backup Kruskal-Wallis Tests ===
# Kruskal-Wallis test for Avg Cosine Similarity: Statistic = 199.6118, p-value = 0.0000
# Kruskal-Wallis test for Avg Pearson Correlation: Statistic = 214.8032, p-value = 0.0000
# Kruskal-Wallis test for Avg Euclidean Distance: Statistic = 195.8250, p-value = 0.0000
