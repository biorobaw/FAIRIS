# %%
import os
os.chdir("../../..")
print(os.getcwd())
# Out:
# /Users/titonka/FAIRIS

# %%
from sklearn.mixture import GaussianMixture
import numpy as np
from sklearn.cluster import KMeans, Birch
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import math
import pickle
import logging
import time

# %%
# Function to plot clusters on the x, y plane
def plot_clusters(xy_list, cluster_labels, name):
    """
    Plot the clusters on the x, y plane using the original (x, y) coordinates, and save the figure.

    Args:
    - xy_list (list of tuples): The original x, y coordinates for each datapoint.
    - cluster_labels (list of int): The cluster label for each datapoint.
    - name (str): The filename to save the figure as (e.g., "clusters_plot.png").
    """
    # Convert xy_list to NumPy arrays for easy plotting
    x_coords = np.array([x for x, y in xy_list])
    y_coords = np.array([y for x, y in xy_list])

    # Check if the lengths match
    if len(x_coords) != len(cluster_labels):
        raise ValueError(f"Mismatch: {len(x_coords)} coordinates and {len(cluster_labels)} cluster labels.")

    # Scatter plot with color coding for clusters
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(x_coords, y_coords, c=cluster_labels, cmap='rainbow', alpha=0.7)

    # Add color bar to indicate clusters
    plt.colorbar(scatter, label='Cluster')

    # Add labels and title
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.title(f'Clustering with {len(set(cluster_labels))} Clusters on X-Y Plane')

    # Save the plot to the specified file
    plt.savefig(name)

    # Close the plot to avoid displaying it when running in scripts
    plt.close()


def plot_clusters_by_subplots(xy_list, theta_list, cluster_labels, name, n_clusters=8):
    """
    Plot the clusters on subplots, one for each cluster, using the original (x, y) coordinates
    and their corresponding direction vectors.

    Args:
    - xy_list (list of tuples): The original x, y coordinates for each datapoint.
    - theta_list (list of floats): The orientation (theta) in degrees for each datapoint.
    - cluster_labels (list of int): The cluster label for each datapoint.
    - name (str): The filename to save the plot.
    - n_clusters (int): Number of clusters to plot.
    """
    # Fixed number of columns
    cols = 5
    # Calculate the number of rows needed
    rows = int(math.ceil(n_clusters / cols))

    # Dynamically scale the figsize based on rows and columns
    width_per_col = 6  # Adjust this for horizontal scaling
    height_per_row = 6  # Adjust this for vertical scaling
    figsize = (cols * width_per_col, rows * height_per_row)

    # Convert xy_list to NumPy arrays for easy filtering and plotting
    x_coords = np.array([x for x, y in xy_list])
    y_coords = np.array([y for x, y in xy_list])
    theta_list = np.array([theta for theta in theta_list])
    # Create subplots
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.flatten()  # Flatten the axes array for easy indexing

    for cluster_id in range(n_clusters):
        # Get the indices of the datapoints that belong to the current cluster
        cluster_indices = np.where(cluster_labels == cluster_id)[0]

        # Filter x and y coordinates for the current cluster
        cluster_x = x_coords[cluster_indices]
        cluster_y = y_coords[cluster_indices]

        # Extract theta values for the current cluster
        cluster_theta = theta_list[cluster_indices]

        # Compute dx and dy for each point in the current cluster
        cluster_dx = 0.5 * np.cos(np.radians(cluster_theta))
        cluster_dy = 0.5 * np.sin(np.radians(cluster_theta))

        # Scatter plot for the current cluster
        axes[cluster_id].scatter(cluster_x, cluster_y, c=f'C{cluster_id}', alpha=0.7, label='Points')

        # Add quiver plot for vectors
        axes[cluster_id].quiver(cluster_x, cluster_y, cluster_dx, cluster_dy, angles='xy', scale_units='xy', scale=1,
                                color='black', alpha=0.7, label='Vectors')

        # Set subplot title and labels
        axes[cluster_id].set_title(f'Cluster {cluster_id}')
        axes[cluster_id].set_xlabel('X Coordinate')
        axes[cluster_id].set_ylabel('Y Coordinate')
        axes[cluster_id].set_xlim(-3, 3)  # Set x-axis limits
        axes[cluster_id].set_ylim(-3, 3)  # Set y-axis limits
        axes[cluster_id].legend()

    # Hide unused subplots (if n_clusters < len(axes))
    for i in range(n_clusters, len(axes)):
        axes[i].axis('off')

    # Adjust layout for better spacing
    plt.tight_layout()

    # Save the plot to the specified file
    fig.savefig(name)
    plt.close()

def format_data_for_clustering(data):
    multimodal_feature_vectors = []
    cnn_feature_vectors = []
    xy_list = []
    theta_list = []
    for observation in data.observations:
        multimodal_feature_vectors.append(observation.multimodal_feature_vector)
        cnn_feature_vectors.append(observation.cnn_feature_vector)
        xy_list.append((observation.x, observation.y))
        theta_list.append(observation.theta)

    return multimodal_feature_vectors, cnn_feature_vectors, xy_list, theta_list


def cluster_with_kmeans_and_save_centers(features_list, n_clusters, centers_save_path):
    """
    Perform KMeans clustering, calculate the maximum distance for each cluster,
    and save the cluster centers and max distances as a list of lists using pickle.

    Args:
    - features_list (list of numpy arrays): The feature vectors extracted from the images.
    - n_clusters (int): The number of clusters to form.
    - centers_save_path (str): Path to save the cluster centers and max distances using pickle.

    Returns:
    - cluster_labels (list of int): The cluster label for each datapoint.
    - cluster_centers (numpy array): The centers of the final clusters.
    """
    features_array = np.array(features_list)

    # Perform KMeans clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(features_array)

    # Get cluster centers and labels for each data point
    cluster_centers = kmeans.cluster_centers_
    labels = kmeans.labels_

    # List to store [center, max_distance] for each cluster
    cluster_data = []

    # Calculate max distance for each cluster
    for cluster_index in range(n_clusters):
        # Get data points belonging to this cluster
        cluster_points = features_array[labels == cluster_index]

        # Calculate distances from each point to the cluster center
        distances = cdist(cluster_points, [cluster_centers[cluster_index]], metric='euclidean').flatten()

        # Find the maximum distance for this cluster
        max_distance = distances.max()

        # Append the center and max distance as a pair to cluster_data
        cluster_data.append([cluster_centers[cluster_index].tolist(), max_distance])

    # Save cluster_data (centers and max distances) using pickle
    with open(centers_save_path, 'wb') as f:
        pickle.dump(cluster_data, f)

    return cluster_labels

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def cluster_with_gmm_and_save_centers(features_list, n_clusters, centers_save_path, use_pca=False, n_components=100):
    """
    Perform Gaussian Mixture Model (GMM) clustering, calculate the maximum distance for each cluster,
    and save the cluster means and max distances as a list of lists using pickle.
    Optionally apply PCA to reduce dimensionality.

    Args:
        features_list (list of numpy arrays): The feature vectors extracted from the images.
        n_clusters (int): The number of clusters to form.
        centers_save_path (str): Path to save the cluster means and max distances using pickle.
        use_pca (bool): Whether to apply PCA for dimensionality reduction. Default is False.
        n_components (int): Number of components to keep if PCA is used. Default is 100.

    Returns:
        cluster_labels (list of int): The cluster label for each datapoint (based on highest probability).
    """
    start_time = time.time()
    logging.info("Starting GMM clustering with %d data points and %d clusters", len(features_list), n_clusters)

    # Convert features_list to numpy array
    try:
        features_array = np.array(features_list, dtype=np.float32)
        if np.any(np.isnan(features_array)) or np.any(np.isinf(features_array)):
            raise ValueError("Feature array contains NaN or infinite values")
    except Exception as e:
        logging.error("Error converting features_list to array: %s", e)
        raise

    # Log feature dimensions
    logging.info("Feature array shape: %s", features_array.shape)

    # Apply PCA if enabled
    if use_pca:
        logging.info("Applying PCA to reduce dimensionality to %d components", n_components)
        try:
            pca = PCA(n_components=n_components)
            features_array = pca.fit_transform(features_array)
            logging.info("PCA reduced shape: %s", features_array.shape)
        except Exception as e:
            logging.error("Error during PCA: %s", e)
            raise

    # Perform GMM clustering
    try:
        gmm = GaussianMixture(
            n_components=n_clusters,
            covariance_type='diag',  # Corrected to 'diag'
            max_iter=50,
            random_state=42,
            verbose=1,
            verbose_interval=10
        )
        gmm.fit(features_array)
        cluster_labels = gmm.predict(features_array)
        logging.info("GMM fitting completed in %.2f seconds", time.time() - start_time)
    except Exception as e:
        logging.error("Error during GMM fitting: %s", e)
        raise

    # Get cluster means (equivalent to centroids)
    cluster_means = gmm.means_

    # List to store [mean, max_distance] for each cluster
    cluster_data = []

    # Calculate max distance for each cluster
    for cluster_index in range(n_clusters):
        # Get data points assigned to this cluster
        cluster_points = features_array[cluster_labels == cluster_index]

        # Calculate distances from each point to the cluster mean
        try:
            distances = cdist(cluster_points, [cluster_means[cluster_index]], metric='euclidean').flatten()
            max_distance = distances.max() if len(distances) > 0 else 0.0
        except Exception as e:
            logging.error("Error calculating distances for cluster %d: %s", cluster_index, e)
            max_distance = 0.0

        # Append the mean and max distance as a pair to cluster_data
        cluster_data.append([cluster_means[cluster_index].tolist(), max_distance])
        logging.info("Cluster %d: %d points, max distance %.2f", cluster_index, len(cluster_points), max_distance)

    # Save cluster_data (means and max distances) using pickle
    try:
        with open(centers_save_path, 'wb') as f:
            pickle.dump(cluster_data, f)
        logging.info("Cluster data saved to %s in %.2f seconds", centers_save_path, time.time() - start_time)
    except Exception as e:
        logging.error("Error saving cluster data: %s", e)
        raise

    return cluster_labels

# %%
data_dir = 'data/VisualPlaceCellData/'
maze_files = ['LM4','LM6','LM8','LMO8','LM8_addition','LMO8_remove']
maze_index = 2

with open(data_dir+maze_files[maze_index]+'_Training','rb') as file:
    visual_place_cell_data = pickle.load(file)

multimodal_feature_vectors,cnn_feature_vectors,xy_list,theta_list = format_data_for_clustering(visual_place_cell_data)
# n_clusters = [50,100,250,500]  # You can change this based on how many clusters you expect
n_clusters = [100,200,400]
for n_cluster in n_clusters:

    centers_save_path = "data/VisualPlaceCellData/VisualPlaceCellClusters/multimodal_gmm_"+str(n_cluster)+"_"+maze_files[maze_index]
    cluster_labels = cluster_with_gmm_and_save_centers(multimodal_feature_vectors, n_cluster, centers_save_path)

    # Now plot the clusters
    plot_clusters_by_subplots(xy_list, theta_list, cluster_labels, "data/figures/Clustering/multimodel_gmm_"+str(n_cluster)+"clusters.png", n_clusters=n_cluster)

    # centers_save_path = "data/VisualPlaceCellData/VisualPlaceCellClusters/cnn_gmm_"+str(n_cluster)+"centers"
    # cluster_labels = cluster_with_gmm_and_save_centers(cnn_feature_vectors, n_cluster, centers_save_path)
    # 
    # # Now plot the clusters
    # plot_clusters_by_subplots(xy_list, theta_list, cluster_labels, "data/figures/Clustering/cnn_gmm_"+str(n_cluster)+"clusters.png", n_clusters=n_cluster)
# Out:
# 2025-07-16 13:29:12,460 - INFO - Starting GMM clustering with 8000 data points and 100 clusters
# 2025-07-16 13:29:12,668 - INFO - Feature array shape: (8000, 7374)
# Initialization 0
#   Iteration 10
#   Iteration 20
# Initialization converged.
# 2025-07-16 13:29:51,291 - INFO - GMM fitting completed in 38.83 seconds
# 2025-07-16 13:29:51,298 - INFO - Cluster 0: 140 points, max distance 2778.69
# 2025-07-16 13:29:51,306 - INFO - Cluster 1: 111 points, max distance 3234.50
# 2025-07-16 13:29:51,309 - INFO - Cluster 2: 88 points, max distance 1976.21
# 2025-07-16 13:29:51,316 - INFO - Cluster 3: 175 points, max distance 2692.34
# 2025-07-16 13:29:51,318 - INFO - Cluster 4: 45 points, max distance 2634.81
# 2025-07-16 13:29:51,322 - INFO - Cluster 5: 75 points, max distance 1712.18
# 2025-07-16 13:29:51,328 - INFO - Cluster 6: 99 points, max distance 3113.56
# 2025-07-16 13:29:51,331 - INFO - Cluster 7: 86 points, max distance 2406.19
# 2025-07-16 13:29:51,333 - INFO - Cluster 8: 51 points, max distance 2661.21
# 2025-07-16 13:29:51,340 - INFO - Cluster 9: 124 points, max distance 2306.92
# 2025-07-16 13:29:51,346 - INFO - Cluster 10: 49 points, max distance 2457.20
# 2025-07-16 13:29:51,348 - INFO - Cluster 11: 43 points, max distance 2693.22
# 2025-07-16 13:29:51,350 - INFO - Cluster 12: 40 points, max distance 2689.96
# 2025-07-16 13:29:51,354 - INFO - Cluster 13: 147 points, max distance 3340.44
# 2025-07-16 13:29:51,356 - INFO - Cluster 14: 85 points, max distance 2520.09
# 2025-07-16 13:29:51,359 - INFO - Cluster 15: 105 points, max distance 3512.01
# 2025-07-16 13:29:51,361 - INFO - Cluster 16: 49 points, max distance 2260.96
# 2025-07-16 13:29:51,365 - INFO - Cluster 17: 66 points, max distance 2759.33
# 2025-07-16 13:29:51,369 - INFO - Cluster 18: 144 points, max distance 3008.18
# 2025-07-16 13:29:51,371 - INFO - Cluster 19: 70 points, max distance 2753.69
# 2025-07-16 13:29:51,373 - INFO - Cluster 20: 61 points, max distance 2782.29
# 2025-07-16 13:29:51,376 - INFO - Cluster 21: 44 points, max distance 2337.17
# 2025-07-16 13:29:51,379 - INFO - Cluster 22: 83 points, max distance 2554.14
# 2025-07-16 13:29:51,381 - INFO - Cluster 23: 73 points, max distance 2475.71
# 2025-07-16 13:29:51,384 - INFO - Cluster 24: 110 points, max distance 2547.86
# 2025-07-16 13:29:51,386 - INFO - Cluster 25: 53 points, max distance 2293.61
# 2025-07-16 13:29:51,389 - INFO - Cluster 26: 112 points, max distance 2451.10
# 2025-07-16 13:29:51,395 - INFO - Cluster 27: 75 points, max distance 2685.10
# 2025-07-16 13:29:51,398 - INFO - Cluster 28: 80 points, max distance 2743.79
# 2025-07-16 13:29:51,401 - INFO - Cluster 29: 155 points, max distance 2459.16
# 2025-07-16 13:29:51,405 - INFO - Cluster 30: 67 points, max distance 3221.86
# 2025-07-16 13:29:51,408 - INFO - Cluster 31: 104 points, max distance 2404.42
# 2025-07-16 13:29:51,414 - INFO - Cluster 32: 96 points, max distance 3051.84
# 2025-07-16 13:29:51,419 - INFO - Cluster 33: 98 points, max distance 3044.22
# 2025-07-16 13:29:51,422 - INFO - Cluster 34: 94 points, max distance 2643.71
# 2025-07-16 13:29:51,427 - INFO - Cluster 35: 38 points, max distance 2795.63
# 2025-07-16 13:29:51,433 - INFO - Cluster 36: 155 points, max distance 3308.66
# 2025-07-16 13:29:51,436 - INFO - Cluster 37: 86 points, max distance 3377.33
# 2025-07-16 13:29:51,441 - INFO - Cluster 38: 29 points, max distance 2777.96
# 2025-07-16 13:29:51,444 - INFO - Cluster 39: 88 points, max distance 2555.35
# 2025-07-16 13:29:51,447 - INFO - Cluster 40: 76 points, max distance 2752.77
# 2025-07-16 13:29:51,450 - INFO - Cluster 41: 130 points, max distance 4721.66
# 2025-07-16 13:29:51,452 - INFO - Cluster 42: 41 points, max distance 2313.84
# 2025-07-16 13:29:51,454 - INFO - Cluster 43: 57 points, max distance 2730.69
# 2025-07-16 13:29:51,456 - INFO - Cluster 44: 69 points, max distance 3251.67
# 2025-07-16 13:29:51,459 - INFO - Cluster 45: 63 points, max distance 2525.14
# 2025-07-16 13:29:51,465 - INFO - Cluster 46: 79 points, max distance 3108.03
# 2025-07-16 13:29:51,467 - INFO - Cluster 47: 47 points, max distance 2803.09
# 2025-07-16 13:29:51,470 - INFO - Cluster 48: 58 points, max distance 2780.88
# 2025-07-16 13:29:51,473 - INFO - Cluster 49: 88 points, max distance 2950.99
# 2025-07-16 13:29:51,476 - INFO - Cluster 50: 64 points, max distance 2323.67
# 2025-07-16 13:29:51,478 - INFO - Cluster 51: 69 points, max distance 2703.55
# 2025-07-16 13:29:51,484 - INFO - Cluster 52: 103 points, max distance 3084.96
# 2025-07-16 13:29:51,487 - INFO - Cluster 53: 26 points, max distance 2877.57
# 2025-07-16 13:29:51,490 - INFO - Cluster 54: 105 points, max distance 2426.64
# 2025-07-16 13:29:51,493 - INFO - Cluster 55: 106 points, max distance 2449.63
# 2025-07-16 13:29:51,497 - INFO - Cluster 56: 168 points, max distance 2454.91
# 2025-07-16 13:29:51,499 - INFO - Cluster 57: 39 points, max distance 3050.72
# 2025-07-16 13:29:51,502 - INFO - Cluster 58: 78 points, max distance 2873.31
# 2025-07-16 13:29:51,506 - INFO - Cluster 59: 61 points, max distance 2351.10
# 2025-07-16 13:29:51,512 - INFO - Cluster 60: 112 points, max distance 2379.63
# 2025-07-16 13:29:51,514 - INFO - Cluster 61: 33 points, max distance 3231.20
# 2025-07-16 13:29:51,516 - INFO - Cluster 62: 63 points, max distance 2523.25
# 2025-07-16 13:29:51,519 - INFO - Cluster 63: 79 points, max distance 2917.28
# 2025-07-16 13:29:51,525 - INFO - Cluster 64: 282 points, max distance 2334.78
# 2025-07-16 13:29:51,528 - INFO - Cluster 65: 61 points, max distance 2921.40
# 2025-07-16 13:29:51,531 - INFO - Cluster 66: 49 points, max distance 2973.94
# 2025-07-16 13:29:51,534 - INFO - Cluster 67: 120 points, max distance 2605.78
# 2025-07-16 13:29:51,536 - INFO - Cluster 68: 53 points, max distance 2458.69
# 2025-07-16 13:29:51,541 - INFO - Cluster 69: 68 points, max distance 2319.45
# 2025-07-16 13:29:51,545 - INFO - Cluster 70: 119 points, max distance 3371.01
# 2025-07-16 13:29:51,550 - INFO - Cluster 71: 116 points, max distance 2702.65
# 2025-07-16 13:29:51,556 - INFO - Cluster 72: 89 points, max distance 2450.71
# 2025-07-16 13:29:51,561 - INFO - Cluster 73: 74 points, max distance 2610.68
# 2025-07-16 13:29:51,563 - INFO - Cluster 74: 38 points, max distance 2527.49
# 2025-07-16 13:29:51,567 - INFO - Cluster 75: 78 points, max distance 2551.29
# 2025-07-16 13:29:51,569 - INFO - Cluster 76: 23 points, max distance 3162.40
# 2025-07-16 13:29:51,571 - INFO - Cluster 77: 80 points, max distance 2609.16
# 2025-07-16 13:29:51,575 - INFO - Cluster 78: 91 points, max distance 2808.35
# 2025-07-16 13:29:51,578 - INFO - Cluster 79: 72 points, max distance 2638.16
# 2025-07-16 13:29:51,580 - INFO - Cluster 80: 53 points, max distance 2887.18
# 2025-07-16 13:29:51,582 - INFO - Cluster 81: 83 points, max distance 2758.27
# 2025-07-16 13:29:51,586 - INFO - Cluster 82: 125 points, max distance 2612.37
# 2025-07-16 13:29:51,590 - INFO - Cluster 83: 67 points, max distance 2619.90
# 2025-07-16 13:29:51,592 - INFO - Cluster 84: 79 points, max distance 2865.63
# 2025-07-16 13:29:51,596 - INFO - Cluster 85: 85 points, max distance 2372.27
# 2025-07-16 13:29:51,598 - INFO - Cluster 86: 29 points, max distance 3230.61
# 2025-07-16 13:29:51,600 - INFO - Cluster 87: 76 points, max distance 2243.27
# 2025-07-16 13:29:51,605 - INFO - Cluster 88: 78 points, max distance 3363.53
# 2025-07-16 13:29:51,607 - INFO - Cluster 89: 62 points, max distance 2778.03
# 2025-07-16 13:29:51,609 - INFO - Cluster 90: 51 points, max distance 2656.60
# 2025-07-16 13:29:51,614 - INFO - Cluster 91: 68 points, max distance 2800.33
# 2025-07-16 13:29:51,616 - INFO - Cluster 92: 8 points, max distance 2874.78
# 2025-07-16 13:29:51,619 - INFO - Cluster 93: 84 points, max distance 2406.31
# 2025-07-16 13:29:51,621 - INFO - Cluster 94: 61 points, max distance 2535.86
# 2025-07-16 13:29:51,626 - INFO - Cluster 95: 67 points, max distance 2409.37
# 2025-07-16 13:29:51,628 - INFO - Cluster 96: 46 points, max distance 2627.78
# 2025-07-16 13:29:51,630 - INFO - Cluster 97: 30 points, max distance 2677.14
# 2025-07-16 13:29:51,632 - INFO - Cluster 98: 51 points, max distance 2604.71
# 2025-07-16 13:29:51,637 - INFO - Cluster 99: 77 points, max distance 2958.86
# 2025-07-16 13:29:51,654 - INFO - Cluster data saved to data/VisualPlaceCellData/VisualPlaceCellClusters/multimodal_gmm_100_LM8 in 39.19 seconds
# 2025-07-16 13:30:02,405 - INFO - Starting GMM clustering with 8000 data points and 200 clusters
# 2025-07-16 13:30:02,525 - INFO - Feature array shape: (8000, 7374)
# Initialization 0
#   Iteration 10
# Initialization converged.
# 2025-07-16 13:30:53,477 - INFO - GMM fitting completed in 51.07 seconds
# 2025-07-16 13:30:53,478 - INFO - Cluster 0: 18 points, max distance 2597.37
# 2025-07-16 13:30:53,481 - INFO - Cluster 1: 45 points, max distance 2680.78
# 2025-07-16 13:30:53,483 - INFO - Cluster 2: 71 points, max distance 2688.72
# 2025-07-16 13:30:53,489 - INFO - Cluster 3: 151 points, max distance 1498.77
# 2025-07-16 13:30:53,490 - INFO - Cluster 4: 24 points, max distance 2384.49
# 2025-07-16 13:30:53,494 - INFO - Cluster 5: 60 points, max distance 2410.86
# 2025-07-16 13:30:53,495 - INFO - Cluster 6: 38 points, max distance 2091.81
# 2025-07-16 13:30:53,497 - INFO - Cluster 7: 29 points, max distance 2253.07
# 2025-07-16 13:30:53,500 - INFO - Cluster 8: 24 points, max distance 1999.57
# 2025-07-16 13:30:53,502 - INFO - Cluster 9: 16 points, max distance 2057.10
# 2025-07-16 13:30:53,504 - INFO - Cluster 10: 39 points, max distance 2549.67
# 2025-07-16 13:30:53,506 - INFO - Cluster 11: 32 points, max distance 2455.07
# 2025-07-16 13:30:53,508 - INFO - Cluster 12: 31 points, max distance 2639.71
# 2025-07-16 13:30:53,511 - INFO - Cluster 13: 50 points, max distance 2461.02
# 2025-07-16 13:30:53,513 - INFO - Cluster 14: 30 points, max distance 2463.09
# 2025-07-16 13:30:53,514 - INFO - Cluster 15: 43 points, max distance 2217.12
# 2025-07-16 13:30:53,516 - INFO - Cluster 16: 34 points, max distance 2265.22
# 2025-07-16 13:30:53,518 - INFO - Cluster 17: 34 points, max distance 2111.10
# 2025-07-16 13:30:53,520 - INFO - Cluster 18: 20 points, max distance 2251.44
# 2025-07-16 13:30:53,521 - INFO - Cluster 19: 45 points, max distance 2574.26
# 2025-07-16 13:30:53,523 - INFO - Cluster 20: 33 points, max distance 2518.49
# 2025-07-16 13:30:53,525 - INFO - Cluster 21: 38 points, max distance 2722.85
# 2025-07-16 13:30:53,529 - INFO - Cluster 22: 39 points, max distance 2316.50
# 2025-07-16 13:30:53,533 - INFO - Cluster 23: 63 points, max distance 2521.26
# 2025-07-16 13:30:53,537 - INFO - Cluster 24: 89 points, max distance 2317.95
# 2025-07-16 13:30:53,539 - INFO - Cluster 25: 56 points, max distance 2078.79
# 2025-07-16 13:30:53,544 - INFO - Cluster 26: 52 points, max distance 2512.31
# 2025-07-16 13:30:53,546 - INFO - Cluster 27: 56 points, max distance 2620.60
# 2025-07-16 13:30:53,552 - INFO - Cluster 28: 65 points, max distance 2360.21
# 2025-07-16 13:30:53,554 - INFO - Cluster 29: 38 points, max distance 2409.58
# 2025-07-16 13:30:53,555 - INFO - Cluster 30: 12 points, max distance 2690.74
# 2025-07-16 13:30:53,557 - INFO - Cluster 31: 33 points, max distance 2280.79
# 2025-07-16 13:30:53,558 - INFO - Cluster 32: 35 points, max distance 2573.71
# 2025-07-16 13:30:53,562 - INFO - Cluster 33: 34 points, max distance 2971.70
# 2025-07-16 13:30:53,564 - INFO - Cluster 34: 42 points, max distance 2215.39
# 2025-07-16 13:30:53,566 - INFO - Cluster 35: 41 points, max distance 2363.38
# 2025-07-16 13:30:53,570 - INFO - Cluster 36: 41 points, max distance 3084.07
# 2025-07-16 13:30:53,572 - INFO - Cluster 37: 20 points, max distance 2656.19
# 2025-07-16 13:30:53,573 - INFO - Cluster 38: 21 points, max distance 1834.80
# 2025-07-16 13:30:53,575 - INFO - Cluster 39: 52 points, max distance 3358.82
# 2025-07-16 13:30:53,579 - INFO - Cluster 40: 47 points, max distance 2831.77
# 2025-07-16 13:30:53,582 - INFO - Cluster 41: 63 points, max distance 2226.83
# 2025-07-16 13:30:53,585 - INFO - Cluster 42: 72 points, max distance 2131.33
# 2025-07-16 13:30:53,587 - INFO - Cluster 43: 34 points, max distance 2778.88
# 2025-07-16 13:30:53,590 - INFO - Cluster 44: 62 points, max distance 2329.27
# 2025-07-16 13:30:53,594 - INFO - Cluster 45: 56 points, max distance 2185.23
# 2025-07-16 13:30:53,596 - INFO - Cluster 46: 34 points, max distance 2458.42
# 2025-07-16 13:30:53,600 - INFO - Cluster 47: 30 points, max distance 2607.49
# 2025-07-16 13:30:53,601 - INFO - Cluster 48: 20 points, max distance 2580.51
# 2025-07-16 13:30:53,604 - INFO - Cluster 49: 42 points, max distance 2722.41
# 2025-07-16 13:30:53,605 - INFO - Cluster 50: 43 points, max distance 2609.59
# 2025-07-16 13:30:53,607 - INFO - Cluster 51: 56 points, max distance 2773.63
# 2025-07-16 13:30:53,609 - INFO - Cluster 52: 19 points, max distance 2582.44
# 2025-07-16 13:30:53,613 - INFO - Cluster 53: 51 points, max distance 1882.82
# 2025-07-16 13:30:53,614 - INFO - Cluster 54: 47 points, max distance 2394.06
# 2025-07-16 13:30:53,616 - INFO - Cluster 55: 12 points, max distance 2770.66
# 2025-07-16 13:30:53,617 - INFO - Cluster 56: 17 points, max distance 3288.99
# 2025-07-16 13:30:53,621 - INFO - Cluster 57: 44 points, max distance 3004.34
# 2025-07-16 13:30:53,622 - INFO - Cluster 58: 33 points, max distance 2587.81
# 2025-07-16 13:30:53,624 - INFO - Cluster 59: 29 points, max distance 2134.17
# 2025-07-16 13:30:53,626 - INFO - Cluster 60: 78 points, max distance 2937.40
# 2025-07-16 13:30:53,628 - INFO - Cluster 61: 50 points, max distance 2680.01
# 2025-07-16 13:30:53,632 - INFO - Cluster 62: 13 points, max distance 2701.13
# 2025-07-16 13:30:53,634 - INFO - Cluster 63: 20 points, max distance 2517.86
# 2025-07-16 13:30:53,635 - INFO - Cluster 64: 18 points, max distance 1941.41
# 2025-07-16 13:30:53,640 - INFO - Cluster 65: 102 points, max distance 2439.55
# 2025-07-16 13:30:53,643 - INFO - Cluster 66: 12 points, max distance 2343.65
# 2025-07-16 13:30:53,644 - INFO - Cluster 67: 35 points, max distance 2543.22
# 2025-07-16 13:30:53,646 - INFO - Cluster 68: 34 points, max distance 2251.13
# 2025-07-16 13:30:53,648 - INFO - Cluster 69: 69 points, max distance 2787.86
# 2025-07-16 13:30:53,653 - INFO - Cluster 70: 17 points, max distance 3139.68
# 2025-07-16 13:30:53,655 - INFO - Cluster 71: 21 points, max distance 2478.09
# 2025-07-16 13:30:53,659 - INFO - Cluster 72: 41 points, max distance 2470.28
# 2025-07-16 13:30:53,661 - INFO - Cluster 73: 47 points, max distance 2162.46
# 2025-07-16 13:30:53,663 - INFO - Cluster 74: 36 points, max distance 2770.20
# 2025-07-16 13:30:53,664 - INFO - Cluster 75: 26 points, max distance 2787.66
# 2025-07-16 13:30:53,665 - INFO - Cluster 76: 19 points, max distance 2399.06
# 2025-07-16 13:30:53,667 - INFO - Cluster 77: 46 points, max distance 2422.29
# 2025-07-16 13:30:53,669 - INFO - Cluster 78: 37 points, max distance 2496.58
# 2025-07-16 13:30:53,670 - INFO - Cluster 79: 9 points, max distance 2498.73
# 2025-07-16 13:30:53,672 - INFO - Cluster 80: 34 points, max distance 2871.69
# 2025-07-16 13:30:53,674 - INFO - Cluster 81: 50 points, max distance 2405.86
# 2025-07-16 13:30:53,676 - INFO - Cluster 82: 71 points, max distance 4286.82
# 2025-07-16 13:30:53,679 - INFO - Cluster 83: 62 points, max distance 2276.03
# 2025-07-16 13:30:53,680 - INFO - Cluster 84: 45 points, max distance 2683.09
# 2025-07-16 13:30:53,682 - INFO - Cluster 85: 40 points, max distance 2846.40
# 2025-07-16 13:30:53,684 - INFO - Cluster 86: 30 points, max distance 2725.26
# 2025-07-16 13:30:53,686 - INFO - Cluster 87: 57 points, max distance 2368.30
# 2025-07-16 13:30:53,688 - INFO - Cluster 88: 40 points, max distance 2037.78
# 2025-07-16 13:30:53,692 - INFO - Cluster 89: 29 points, max distance 2255.42
# 2025-07-16 13:30:53,698 - INFO - Cluster 90: 96 points, max distance 2691.86
# 2025-07-16 13:30:53,701 - INFO - Cluster 91: 68 points, max distance 2636.47
# 2025-07-16 13:30:53,703 - INFO - Cluster 92: 29 points, max distance 2253.89
# 2025-07-16 13:30:53,705 - INFO - Cluster 93: 48 points, max distance 2102.48
# 2025-07-16 13:30:53,706 - INFO - Cluster 94: 44 points, max distance 2682.58
# 2025-07-16 13:30:53,711 - INFO - Cluster 95: 27 points, max distance 2418.70
# 2025-07-16 13:30:53,712 - INFO - Cluster 96: 18 points, max distance 2493.00
# 2025-07-16 13:30:53,714 - INFO - Cluster 97: 32 points, max distance 2864.74
# 2025-07-16 13:30:53,716 - INFO - Cluster 98: 23 points, max distance 2415.23
# 2025-07-16 13:30:53,718 - INFO - Cluster 99: 16 points, max distance 2353.99
# 2025-07-16 13:30:53,719 - INFO - Cluster 100: 30 points, max distance 2538.58
# 2025-07-16 13:30:53,720 - INFO - Cluster 101: 27 points, max distance 2471.07
# 2025-07-16 13:30:53,722 - INFO - Cluster 102: 13 points, max distance 2775.00
# 2025-07-16 13:30:53,724 - INFO - Cluster 103: 46 points, max distance 2435.01
# 2025-07-16 13:30:53,726 - INFO - Cluster 104: 52 points, max distance 2759.15
# 2025-07-16 13:30:53,728 - INFO - Cluster 105: 57 points, max distance 2583.68
# 2025-07-16 13:30:53,731 - INFO - Cluster 106: 25 points, max distance 2731.47
# 2025-07-16 13:30:53,732 - INFO - Cluster 107: 30 points, max distance 2452.19
# 2025-07-16 13:30:53,736 - INFO - Cluster 108: 48 points, max distance 2211.07
# 2025-07-16 13:30:53,738 - INFO - Cluster 109: 41 points, max distance 2488.42
# 2025-07-16 13:30:53,739 - INFO - Cluster 110: 32 points, max distance 2499.96
# 2025-07-16 13:30:53,742 - INFO - Cluster 111: 32 points, max distance 2681.42
# 2025-07-16 13:30:53,745 - INFO - Cluster 112: 60 points, max distance 2641.86
# 2025-07-16 13:30:53,747 - INFO - Cluster 113: 16 points, max distance 2091.79
# 2025-07-16 13:30:53,749 - INFO - Cluster 114: 23 points, max distance 2718.94
# 2025-07-16 13:30:53,752 - INFO - Cluster 115: 37 points, max distance 2553.31
# 2025-07-16 13:30:53,754 - INFO - Cluster 116: 53 points, max distance 2347.71
# 2025-07-16 13:30:53,759 - INFO - Cluster 117: 170 points, max distance 2364.35
# 2025-07-16 13:30:53,762 - INFO - Cluster 118: 41 points, max distance 2585.91
# 2025-07-16 13:30:53,764 - INFO - Cluster 119: 57 points, max distance 2461.58
# 2025-07-16 13:30:53,766 - INFO - Cluster 120: 57 points, max distance 2430.36
# 2025-07-16 13:30:53,772 - INFO - Cluster 121: 58 points, max distance 2372.86
# 2025-07-16 13:30:53,775 - INFO - Cluster 122: 87 points, max distance 2818.58
# 2025-07-16 13:30:53,776 - INFO - Cluster 123: 39 points, max distance 2582.88
# 2025-07-16 13:30:53,779 - INFO - Cluster 124: 31 points, max distance 2169.77
# 2025-07-16 13:30:53,781 - INFO - Cluster 125: 52 points, max distance 2513.53
# 2025-07-16 13:30:53,782 - INFO - Cluster 126: 26 points, max distance 2340.40
# 2025-07-16 13:30:53,785 - INFO - Cluster 127: 61 points, max distance 2884.08
# 2025-07-16 13:30:53,787 - INFO - Cluster 128: 63 points, max distance 2691.91
# 2025-07-16 13:30:53,790 - INFO - Cluster 129: 49 points, max distance 2346.65
# 2025-07-16 13:30:53,795 - INFO - Cluster 130: 33 points, max distance 2759.34
# 2025-07-16 13:30:53,797 - INFO - Cluster 131: 52 points, max distance 2859.90
# 2025-07-16 13:30:53,799 - INFO - Cluster 132: 15 points, max distance 2611.84
# 2025-07-16 13:30:53,801 - INFO - Cluster 133: 31 points, max distance 2289.30
# 2025-07-16 13:30:53,803 - INFO - Cluster 134: 26 points, max distance 3043.86
# 2025-07-16 13:30:53,806 - INFO - Cluster 135: 53 points, max distance 2970.96
# 2025-07-16 13:30:53,807 - INFO - Cluster 136: 30 points, max distance 2055.69
# 2025-07-16 13:30:53,813 - INFO - Cluster 137: 67 points, max distance 2212.55
# 2025-07-16 13:30:53,814 - INFO - Cluster 138: 36 points, max distance 2426.36
# 2025-07-16 13:30:53,816 - INFO - Cluster 139: 50 points, max distance 2670.87
# 2025-07-16 13:30:53,821 - INFO - Cluster 140: 34 points, max distance 2754.24
# 2025-07-16 13:30:53,823 - INFO - Cluster 141: 19 points, max distance 2512.62
# 2025-07-16 13:30:53,825 - INFO - Cluster 142: 34 points, max distance 2296.51
# 2025-07-16 13:30:53,827 - INFO - Cluster 143: 33 points, max distance 2816.94
# 2025-07-16 13:30:53,829 - INFO - Cluster 144: 28 points, max distance 2525.12
# 2025-07-16 13:30:53,830 - INFO - Cluster 145: 22 points, max distance 2678.36
# 2025-07-16 13:30:53,832 - INFO - Cluster 146: 48 points, max distance 2812.64
# 2025-07-16 13:30:53,835 - INFO - Cluster 147: 38 points, max distance 2922.29
# 2025-07-16 13:30:53,840 - INFO - Cluster 148: 133 points, max distance 2202.09
# 2025-07-16 13:30:53,841 - INFO - Cluster 149: 32 points, max distance 2440.93
# 2025-07-16 13:30:53,854 - INFO - Cluster 150: 33 points, max distance 2720.00
# 2025-07-16 13:30:53,855 - INFO - Cluster 151: 17 points, max distance 2337.03
# 2025-07-16 13:30:53,857 - INFO - Cluster 152: 7 points, max distance 2727.52
# 2025-07-16 13:30:53,861 - INFO - Cluster 153: 24 points, max distance 2282.76
# 2025-07-16 13:30:53,863 - INFO - Cluster 154: 18 points, max distance 2901.53
# 2025-07-16 13:30:53,866 - INFO - Cluster 155: 33 points, max distance 2770.84
# 2025-07-16 13:30:53,872 - INFO - Cluster 156: 61 points, max distance 2662.85
# 2025-07-16 13:30:53,874 - INFO - Cluster 157: 27 points, max distance 2602.56
# 2025-07-16 13:30:53,876 - INFO - Cluster 158: 19 points, max distance 2848.02
# 2025-07-16 13:30:53,877 - INFO - Cluster 159: 24 points, max distance 2155.34
# 2025-07-16 13:30:53,879 - INFO - Cluster 160: 25 points, max distance 2288.95
# 2025-07-16 13:30:53,881 - INFO - Cluster 161: 35 points, max distance 2274.04
# 2025-07-16 13:30:53,882 - INFO - Cluster 162: 16 points, max distance 1991.46
# 2025-07-16 13:30:53,884 - INFO - Cluster 163: 26 points, max distance 2313.47
# 2025-07-16 13:30:53,889 - INFO - Cluster 164: 28 points, max distance 2430.84
# 2025-07-16 13:30:53,893 - INFO - Cluster 165: 40 points, max distance 2490.24
# 2025-07-16 13:30:53,895 - INFO - Cluster 166: 20 points, max distance 2773.57
# 2025-07-16 13:30:53,898 - INFO - Cluster 167: 28 points, max distance 2722.83
# 2025-07-16 13:30:53,900 - INFO - Cluster 168: 28 points, max distance 2721.76
# 2025-07-16 13:30:53,901 - INFO - Cluster 169: 35 points, max distance 2729.52
# 2025-07-16 13:30:53,903 - INFO - Cluster 170: 44 points, max distance 2610.01
# 2025-07-16 13:30:53,908 - INFO - Cluster 171: 34 points, max distance 2924.01
# 2025-07-16 13:30:53,910 - INFO - Cluster 172: 25 points, max distance 2269.71
# 2025-07-16 13:30:53,912 - INFO - Cluster 173: 45 points, max distance 2261.24
# 2025-07-16 13:30:53,914 - INFO - Cluster 174: 26 points, max distance 2250.48
# 2025-07-16 13:30:53,916 - INFO - Cluster 175: 41 points, max distance 2210.73
# 2025-07-16 13:30:53,917 - INFO - Cluster 176: 43 points, max distance 2639.73
# 2025-07-16 13:30:53,922 - INFO - Cluster 177: 33 points, max distance 2199.54
# 2025-07-16 13:30:53,923 - INFO - Cluster 178: 34 points, max distance 2641.74
# 2025-07-16 13:30:53,928 - INFO - Cluster 179: 10 points, max distance 2546.01
# 2025-07-16 13:30:53,931 - INFO - Cluster 180: 48 points, max distance 2410.69
# 2025-07-16 13:30:53,935 - INFO - Cluster 181: 28 points, max distance 2009.87
# 2025-07-16 13:30:53,939 - INFO - Cluster 182: 29 points, max distance 2286.51
# 2025-07-16 13:30:53,942 - INFO - Cluster 183: 25 points, max distance 2286.93
# 2025-07-16 13:30:53,946 - INFO - Cluster 184: 25 points, max distance 1888.34
# 2025-07-16 13:30:53,948 - INFO - Cluster 185: 30 points, max distance 2068.61
# 2025-07-16 13:30:53,952 - INFO - Cluster 186: 43 points, max distance 2636.50
# 2025-07-16 13:30:53,955 - INFO - Cluster 187: 39 points, max distance 2348.58
# 2025-07-16 13:30:53,959 - INFO - Cluster 188: 44 points, max distance 2791.68
# 2025-07-16 13:30:53,961 - INFO - Cluster 189: 32 points, max distance 2486.05
# 2025-07-16 13:30:53,964 - INFO - Cluster 190: 84 points, max distance 2358.58
# 2025-07-16 13:30:53,966 - INFO - Cluster 191: 16 points, max distance 2406.12
# 2025-07-16 13:30:53,968 - INFO - Cluster 192: 50 points, max distance 2547.74
# 2025-07-16 13:30:53,971 - INFO - Cluster 193: 25 points, max distance 2135.32
# 2025-07-16 13:30:53,972 - INFO - Cluster 194: 19 points, max distance 2304.93
# 2025-07-16 13:30:53,975 - INFO - Cluster 195: 30 points, max distance 1988.31
# 2025-07-16 13:30:53,977 - INFO - Cluster 196: 69 points, max distance 2126.76
# 2025-07-16 13:30:53,979 - INFO - Cluster 197: 42 points, max distance 2530.18
# 2025-07-16 13:30:53,981 - INFO - Cluster 198: 43 points, max distance 2381.10
# 2025-07-16 13:30:53,984 - INFO - Cluster 199: 79 points, max distance 3549.86
# 2025-07-16 13:30:54,022 - INFO - Cluster data saved to data/VisualPlaceCellData/VisualPlaceCellClusters/multimodal_gmm_200_LM8 in 51.62 seconds
# 2025-07-16 13:31:16,204 - INFO - Starting GMM clustering with 8000 data points and 400 clusters
# 2025-07-16 13:31:16,327 - INFO - Feature array shape: (8000, 7374)
# Initialization 0
#   Iteration 10
# Initialization converged.
# 2025-07-16 13:32:50,023 - INFO - GMM fitting completed in 93.82 seconds
# 2025-07-16 13:32:50,025 - INFO - Cluster 0: 9 points, max distance 1742.55
# 2025-07-16 13:32:50,027 - INFO - Cluster 1: 22 points, max distance 2664.34
# 2025-07-16 13:32:50,029 - INFO - Cluster 2: 19 points, max distance 2019.70
# 2025-07-16 13:32:50,032 - INFO - Cluster 3: 73 points, max distance 1248.18
# 2025-07-16 13:32:50,034 - INFO - Cluster 4: 16 points, max distance 2234.19
# 2025-07-16 13:32:50,035 - INFO - Cluster 5: 11 points, max distance 2467.72
# 2025-07-16 13:32:50,037 - INFO - Cluster 6: 34 points, max distance 1947.09
# 2025-07-16 13:32:50,039 - INFO - Cluster 7: 18 points, max distance 2505.16
# 2025-07-16 13:32:50,043 - INFO - Cluster 8: 22 points, max distance 2088.19
# 2025-07-16 13:32:50,044 - INFO - Cluster 9: 12 points, max distance 1999.94
# 2025-07-16 13:32:50,046 - INFO - Cluster 10: 17 points, max distance 2085.01
# 2025-07-16 13:32:50,048 - INFO - Cluster 11: 11 points, max distance 2324.17
# 2025-07-16 13:32:50,051 - INFO - Cluster 12: 19 points, max distance 2297.30
# 2025-07-16 13:32:50,053 - INFO - Cluster 13: 11 points, max distance 2120.59
# 2025-07-16 13:32:50,054 - INFO - Cluster 14: 18 points, max distance 2044.19
# 2025-07-16 13:32:50,058 - INFO - Cluster 15: 30 points, max distance 1945.99
# 2025-07-16 13:32:50,060 - INFO - Cluster 16: 33 points, max distance 1946.03
# 2025-07-16 13:32:50,063 - INFO - Cluster 17: 24 points, max distance 2175.69
# 2025-07-16 13:32:50,064 - INFO - Cluster 18: 18 points, max distance 2184.54
# 2025-07-16 13:32:50,068 - INFO - Cluster 19: 23 points, max distance 2227.16
# 2025-07-16 13:32:50,070 - INFO - Cluster 20: 17 points, max distance 2451.62
# 2025-07-16 13:32:50,072 - INFO - Cluster 21: 25 points, max distance 2148.21
# 2025-07-16 13:32:50,075 - INFO - Cluster 22: 29 points, max distance 1831.92
# 2025-07-16 13:32:50,077 - INFO - Cluster 23: 22 points, max distance 2123.98
# 2025-07-16 13:32:50,079 - INFO - Cluster 24: 41 points, max distance 2135.74
# 2025-07-16 13:32:50,081 - INFO - Cluster 25: 17 points, max distance 1626.64
# 2025-07-16 13:32:50,085 - INFO - Cluster 26: 30 points, max distance 2412.08
# 2025-07-16 13:32:50,086 - INFO - Cluster 27: 16 points, max distance 2253.66
# 2025-07-16 13:32:50,088 - INFO - Cluster 28: 38 points, max distance 2300.84
# 2025-07-16 13:32:50,090 - INFO - Cluster 29: 15 points, max distance 2152.80
# 2025-07-16 13:32:50,091 - INFO - Cluster 30: 10 points, max distance 2444.80
# 2025-07-16 13:32:50,094 - INFO - Cluster 31: 27 points, max distance 2596.46
# 2025-07-16 13:32:50,097 - INFO - Cluster 32: 16 points, max distance 2556.05
# 2025-07-16 13:32:50,100 - INFO - Cluster 33: 29 points, max distance 2776.87
# 2025-07-16 13:32:50,101 - INFO - Cluster 34: 21 points, max distance 2093.83
# 2025-07-16 13:32:50,104 - INFO - Cluster 35: 36 points, max distance 2140.81
# 2025-07-16 13:32:50,106 - INFO - Cluster 36: 22 points, max distance 2135.27
# 2025-07-16 13:32:50,107 - INFO - Cluster 37: 9 points, max distance 2243.93
# 2025-07-16 13:32:50,109 - INFO - Cluster 38: 17 points, max distance 1942.46
# 2025-07-16 13:32:50,112 - INFO - Cluster 39: 22 points, max distance 2464.34
# 2025-07-16 13:32:50,114 - INFO - Cluster 40: 24 points, max distance 2620.19
# 2025-07-16 13:32:50,116 - INFO - Cluster 41: 24 points, max distance 1973.85
# 2025-07-16 13:32:50,118 - INFO - Cluster 42: 27 points, max distance 2018.37
# 2025-07-16 13:32:50,119 - INFO - Cluster 43: 18 points, max distance 2281.48
# 2025-07-16 13:32:50,123 - INFO - Cluster 44: 32 points, max distance 2427.60
# 2025-07-16 13:32:50,124 - INFO - Cluster 45: 28 points, max distance 2350.29
# 2025-07-16 13:32:50,127 - INFO - Cluster 46: 34 points, max distance 2122.31
# 2025-07-16 13:32:50,128 - INFO - Cluster 47: 14 points, max distance 2027.01
# 2025-07-16 13:32:50,132 - INFO - Cluster 48: 18 points, max distance 2451.88
# 2025-07-16 13:32:50,134 - INFO - Cluster 49: 16 points, max distance 2206.52
# 2025-07-16 13:32:50,136 - INFO - Cluster 50: 20 points, max distance 2251.11
# 2025-07-16 13:32:50,139 - INFO - Cluster 51: 24 points, max distance 2215.02
# 2025-07-16 13:32:50,140 - INFO - Cluster 52: 7 points, max distance 2304.40
# 2025-07-16 13:32:50,144 - INFO - Cluster 53: 20 points, max distance 2423.14
# 2025-07-16 13:32:50,146 - INFO - Cluster 54: 20 points, max distance 1936.94
# 2025-07-16 13:32:50,147 - INFO - Cluster 55: 10 points, max distance 2289.87
# 2025-07-16 13:32:50,149 - INFO - Cluster 56: 9 points, max distance 2297.03
# 2025-07-16 13:32:50,152 - INFO - Cluster 57: 15 points, max distance 2842.33
# 2025-07-16 13:32:50,154 - INFO - Cluster 58: 20 points, max distance 2452.50
# 2025-07-16 13:32:50,155 - INFO - Cluster 59: 24 points, max distance 2102.58
# 2025-07-16 13:32:50,158 - INFO - Cluster 60: 45 points, max distance 2761.16
# 2025-07-16 13:32:50,161 - INFO - Cluster 61: 18 points, max distance 1950.60
# 2025-07-16 13:32:50,163 - INFO - Cluster 62: 49 points, max distance 1914.60
# 2025-07-16 13:32:50,165 - INFO - Cluster 63: 10 points, max distance 2222.93
# 2025-07-16 13:32:50,168 - INFO - Cluster 64: 11 points, max distance 2161.35
# 2025-07-16 13:32:50,174 - INFO - Cluster 65: 77 points, max distance 2183.54
# 2025-07-16 13:32:50,177 - INFO - Cluster 66: 12 points, max distance 2343.65
# 2025-07-16 13:32:50,178 - INFO - Cluster 67: 7 points, max distance 1775.38
# 2025-07-16 13:32:50,180 - INFO - Cluster 68: 21 points, max distance 2092.57
# 2025-07-16 13:32:50,183 - INFO - Cluster 69: 24 points, max distance 2524.99
# 2025-07-16 13:32:50,184 - INFO - Cluster 70: 6 points, max distance 2453.50
# 2025-07-16 13:32:50,186 - INFO - Cluster 71: 16 points, max distance 1958.83
# 2025-07-16 13:32:50,188 - INFO - Cluster 72: 19 points, max distance 2452.67
# 2025-07-16 13:32:50,189 - INFO - Cluster 73: 12 points, max distance 1948.36
# 2025-07-16 13:32:50,193 - INFO - Cluster 74: 22 points, max distance 2475.34
# 2025-07-16 13:32:50,195 - INFO - Cluster 75: 12 points, max distance 2853.99
# 2025-07-16 13:32:50,196 - INFO - Cluster 76: 9 points, max distance 2332.12
# 2025-07-16 13:32:50,198 - INFO - Cluster 77: 8 points, max distance 2229.42
# 2025-07-16 13:32:50,201 - INFO - Cluster 78: 11 points, max distance 1950.78
# 2025-07-16 13:32:50,203 - INFO - Cluster 79: 6 points, max distance 2687.62
# 2025-07-16 13:32:50,205 - INFO - Cluster 80: 19 points, max distance 2256.57
# 2025-07-16 13:32:50,208 - INFO - Cluster 81: 33 points, max distance 2212.61
# 2025-07-16 13:32:50,210 - INFO - Cluster 82: 25 points, max distance 2308.13
# 2025-07-16 13:32:50,212 - INFO - Cluster 83: 29 points, max distance 1940.89
# 2025-07-16 13:32:50,215 - INFO - Cluster 84: 19 points, max distance 2357.87
# 2025-07-16 13:32:50,217 - INFO - Cluster 85: 19 points, max distance 2206.29
# 2025-07-16 13:32:50,219 - INFO - Cluster 86: 13 points, max distance 2407.92
# 2025-07-16 13:32:50,222 - INFO - Cluster 87: 40 points, max distance 1995.57
# 2025-07-16 13:32:50,223 - INFO - Cluster 88: 29 points, max distance 2083.21
# 2025-07-16 13:32:50,225 - INFO - Cluster 89: 16 points, max distance 2199.54
# 2025-07-16 13:32:50,229 - INFO - Cluster 90: 29 points, max distance 2509.66
# 2025-07-16 13:32:50,234 - INFO - Cluster 91: 50 points, max distance 2263.86
# 2025-07-16 13:32:50,236 - INFO - Cluster 92: 28 points, max distance 2227.81
# 2025-07-16 13:32:50,238 - INFO - Cluster 93: 38 points, max distance 2283.65
# 2025-07-16 13:32:50,239 - INFO - Cluster 94: 19 points, max distance 2390.44
# 2025-07-16 13:32:50,241 - INFO - Cluster 95: 15 points, max distance 1972.25
# 2025-07-16 13:32:50,243 - INFO - Cluster 96: 11 points, max distance 2233.19
# 2025-07-16 13:32:50,245 - INFO - Cluster 97: 23 points, max distance 2214.62
# 2025-07-16 13:32:50,247 - INFO - Cluster 98: 16 points, max distance 2363.53
# 2025-07-16 13:32:50,251 - INFO - Cluster 99: 9 points, max distance 2024.65
# 2025-07-16 13:32:50,253 - INFO - Cluster 100: 22 points, max distance 2352.71
# 2025-07-16 13:32:50,255 - INFO - Cluster 101: 16 points, max distance 2662.16
# 2025-07-16 13:32:50,257 - INFO - Cluster 102: 6 points, max distance 2312.40
# 2025-07-16 13:32:50,260 - INFO - Cluster 103: 25 points, max distance 2196.61
# 2025-07-16 13:32:50,262 - INFO - Cluster 104: 28 points, max distance 2335.05
# 2025-07-16 13:32:50,264 - INFO - Cluster 105: 40 points, max distance 2516.46
# 2025-07-16 13:32:50,280 - INFO - Cluster 106: 17 points, max distance 2561.23
# 2025-07-16 13:32:50,283 - INFO - Cluster 107: 23 points, max distance 2244.92
# 2025-07-16 13:32:50,285 - INFO - Cluster 108: 27 points, max distance 2211.32
# 2025-07-16 13:32:50,287 - INFO - Cluster 109: 15 points, max distance 2115.20
# 2025-07-16 13:32:50,288 - INFO - Cluster 110: 16 points, max distance 2223.48
# 2025-07-16 13:32:50,290 - INFO - Cluster 111: 30 points, max distance 2227.93
# 2025-07-16 13:32:50,291 - INFO - Cluster 112: 28 points, max distance 2084.13
# 2025-07-16 13:32:50,293 - INFO - Cluster 113: 8 points, max distance 2293.65
# 2025-07-16 13:32:50,294 - INFO - Cluster 114: 20 points, max distance 2162.74
# 2025-07-16 13:32:50,297 - INFO - Cluster 115: 28 points, max distance 2486.26
# 2025-07-16 13:32:50,301 - INFO - Cluster 116: 44 points, max distance 2030.68
# 2025-07-16 13:32:50,303 - INFO - Cluster 117: 48 points, max distance 1882.10
# 2025-07-16 13:32:50,305 - INFO - Cluster 118: 25 points, max distance 2147.91
# 2025-07-16 13:32:50,306 - INFO - Cluster 119: 12 points, max distance 1904.55
# 2025-07-16 13:32:50,308 - INFO - Cluster 120: 27 points, max distance 2498.52
# 2025-07-16 13:32:50,312 - INFO - Cluster 121: 22 points, max distance 1936.24
# 2025-07-16 13:32:50,316 - INFO - Cluster 122: 37 points, max distance 2652.17
# 2025-07-16 13:32:50,319 - INFO - Cluster 123: 33 points, max distance 2549.78
# 2025-07-16 13:32:50,321 - INFO - Cluster 124: 16 points, max distance 2012.12
# 2025-07-16 13:32:50,323 - INFO - Cluster 125: 27 points, max distance 2141.22
# 2025-07-16 13:32:50,325 - INFO - Cluster 126: 28 points, max distance 2360.84
# 2025-07-16 13:32:50,329 - INFO - Cluster 127: 28 points, max distance 2743.55
# 2025-07-16 13:32:50,334 - INFO - Cluster 128: 96 points, max distance 2555.74
# 2025-07-16 13:32:50,338 - INFO - Cluster 129: 26 points, max distance 2337.75
# 2025-07-16 13:32:50,341 - INFO - Cluster 130: 18 points, max distance 2085.31
# 2025-07-16 13:32:50,343 - INFO - Cluster 131: 24 points, max distance 2421.74
# 2025-07-16 13:32:50,344 - INFO - Cluster 132: 14 points, max distance 2556.94
# 2025-07-16 13:32:50,346 - INFO - Cluster 133: 22 points, max distance 2283.09
# 2025-07-16 13:32:50,347 - INFO - Cluster 134: 9 points, max distance 2272.08
# 2025-07-16 13:32:50,352 - INFO - Cluster 135: 25 points, max distance 2791.60
# 2025-07-16 13:32:50,353 - INFO - Cluster 136: 15 points, max distance 1798.97
# 2025-07-16 13:32:50,357 - INFO - Cluster 137: 37 points, max distance 2196.87
# 2025-07-16 13:32:50,358 - INFO - Cluster 138: 17 points, max distance 1961.28
# 2025-07-16 13:32:50,360 - INFO - Cluster 139: 18 points, max distance 2320.32
# 2025-07-16 13:32:50,362 - INFO - Cluster 140: 15 points, max distance 2108.23
# 2025-07-16 13:32:50,364 - INFO - Cluster 141: 19 points, max distance 2455.69
# 2025-07-16 13:32:50,366 - INFO - Cluster 142: 15 points, max distance 1766.79
# 2025-07-16 13:32:50,367 - INFO - Cluster 143: 12 points, max distance 2013.48
# 2025-07-16 13:32:50,369 - INFO - Cluster 144: 12 points, max distance 2330.09
# 2025-07-16 13:32:50,370 - INFO - Cluster 145: 18 points, max distance 2446.26
# 2025-07-16 13:32:50,373 - INFO - Cluster 146: 20 points, max distance 2972.16
# 2025-07-16 13:32:50,374 - INFO - Cluster 147: 16 points, max distance 3049.89
# 2025-07-16 13:32:50,379 - INFO - Cluster 148: 79 points, max distance 2050.01
# 2025-07-16 13:32:50,381 - INFO - Cluster 149: 25 points, max distance 2099.00
# 2025-07-16 13:32:50,384 - INFO - Cluster 150: 19 points, max distance 2228.73
# 2025-07-16 13:32:50,387 - INFO - Cluster 151: 17 points, max distance 2337.03
# 2025-07-16 13:32:50,388 - INFO - Cluster 152: 7 points, max distance 2727.52
# 2025-07-16 13:32:50,390 - INFO - Cluster 153: 10 points, max distance 2241.08
# 2025-07-16 13:32:50,391 - INFO - Cluster 154: 11 points, max distance 2905.89
# 2025-07-16 13:32:50,395 - INFO - Cluster 155: 25 points, max distance 2087.53
# 2025-07-16 13:32:50,398 - INFO - Cluster 156: 30 points, max distance 2242.67
# 2025-07-16 13:32:50,400 - INFO - Cluster 157: 11 points, max distance 2100.67
# 2025-07-16 13:32:50,402 - INFO - Cluster 158: 19 points, max distance 2848.02
# 2025-07-16 13:32:50,404 - INFO - Cluster 159: 21 points, max distance 2193.72
# 2025-07-16 13:32:50,406 - INFO - Cluster 160: 17 points, max distance 2292.38
# 2025-07-16 13:32:50,407 - INFO - Cluster 161: 15 points, max distance 1964.38
# 2025-07-16 13:32:50,410 - INFO - Cluster 162: 15 points, max distance 1931.63
# 2025-07-16 13:32:50,412 - INFO - Cluster 163: 17 points, max distance 2322.70
# 2025-07-16 13:32:50,413 - INFO - Cluster 164: 20 points, max distance 2251.34
# 2025-07-16 13:32:50,417 - INFO - Cluster 165: 18 points, max distance 1829.31
# 2025-07-16 13:32:50,418 - INFO - Cluster 166: 6 points, max distance 2170.52
# 2025-07-16 13:32:50,420 - INFO - Cluster 167: 4 points, max distance 1528.38
# 2025-07-16 13:32:50,421 - INFO - Cluster 168: 23 points, max distance 2041.67
# 2025-07-16 13:32:50,423 - INFO - Cluster 169: 22 points, max distance 2323.27
# 2025-07-16 13:32:50,426 - INFO - Cluster 170: 21 points, max distance 2520.90
# 2025-07-16 13:32:50,429 - INFO - Cluster 171: 13 points, max distance 1884.46
# 2025-07-16 13:32:50,431 - INFO - Cluster 172: 22 points, max distance 2215.74
# 2025-07-16 13:32:50,432 - INFO - Cluster 173: 17 points, max distance 1853.29
# 2025-07-16 13:32:50,434 - INFO - Cluster 174: 21 points, max distance 2200.83
# 2025-07-16 13:32:50,436 - INFO - Cluster 175: 30 points, max distance 2159.09
# 2025-07-16 13:32:50,438 - INFO - Cluster 176: 22 points, max distance 1537.09
# 2025-07-16 13:32:50,440 - INFO - Cluster 177: 23 points, max distance 1741.99
# 2025-07-16 13:32:50,443 - INFO - Cluster 178: 16 points, max distance 2432.32
# 2025-07-16 13:32:50,445 - INFO - Cluster 179: 3 points, max distance 2007.68
# 2025-07-16 13:32:50,446 - INFO - Cluster 180: 14 points, max distance 2134.16
# 2025-07-16 13:32:50,448 - INFO - Cluster 181: 20 points, max distance 1895.01
# 2025-07-16 13:32:50,450 - INFO - Cluster 182: 14 points, max distance 2021.48
# 2025-07-16 13:32:50,453 - INFO - Cluster 183: 14 points, max distance 1805.59
# 2025-07-16 13:32:50,455 - INFO - Cluster 184: 20 points, max distance 1776.45
# 2025-07-16 13:32:50,458 - INFO - Cluster 185: 22 points, max distance 2439.21
# 2025-07-16 13:32:50,459 - INFO - Cluster 186: 22 points, max distance 2470.75
# 2025-07-16 13:32:50,461 - INFO - Cluster 187: 29 points, max distance 2502.09
# 2025-07-16 13:32:50,465 - INFO - Cluster 188: 30 points, max distance 2453.98
# 2025-07-16 13:32:50,468 - INFO - Cluster 189: 22 points, max distance 2569.71
# 2025-07-16 13:32:50,471 - INFO - Cluster 190: 47 points, max distance 2080.96
# 2025-07-16 13:32:50,473 - INFO - Cluster 191: 14 points, max distance 2864.94
# 2025-07-16 13:32:50,474 - INFO - Cluster 192: 15 points, max distance 2101.33
# 2025-07-16 13:32:50,476 - INFO - Cluster 193: 26 points, max distance 2154.11
# 2025-07-16 13:32:50,478 - INFO - Cluster 194: 14 points, max distance 2237.77
# 2025-07-16 13:32:50,481 - INFO - Cluster 195: 18 points, max distance 2020.25
# 2025-07-16 13:32:50,483 - INFO - Cluster 196: 51 points, max distance 1939.00
# 2025-07-16 13:32:50,487 - INFO - Cluster 197: 23 points, max distance 2505.50
# 2025-07-16 13:32:50,489 - INFO - Cluster 198: 35 points, max distance 2648.88
# 2025-07-16 13:32:50,491 - INFO - Cluster 199: 21 points, max distance 3196.53
# 2025-07-16 13:32:50,493 - INFO - Cluster 200: 13 points, max distance 2085.17
# 2025-07-16 13:32:50,496 - INFO - Cluster 201: 16 points, max distance 2473.72
# 2025-07-16 13:32:50,497 - INFO - Cluster 202: 8 points, max distance 2085.47
# 2025-07-16 13:32:50,500 - INFO - Cluster 203: 12 points, max distance 2088.66
# 2025-07-16 13:32:50,501 - INFO - Cluster 204: 9 points, max distance 1973.01
# 2025-07-16 13:32:50,503 - INFO - Cluster 205: 7 points, max distance 1695.46
# 2025-07-16 13:32:50,504 - INFO - Cluster 206: 14 points, max distance 2573.98
# 2025-07-16 13:32:50,506 - INFO - Cluster 207: 30 points, max distance 1855.67
# 2025-07-16 13:32:50,509 - INFO - Cluster 208: 32 points, max distance 2245.26
# 2025-07-16 13:32:50,513 - INFO - Cluster 209: 16 points, max distance 2195.73
# 2025-07-16 13:32:50,516 - INFO - Cluster 210: 17 points, max distance 1954.68
# 2025-07-16 13:32:50,518 - INFO - Cluster 211: 7 points, max distance 2557.72
# 2025-07-16 13:32:50,522 - INFO - Cluster 212: 26 points, max distance 2136.77
# 2025-07-16 13:32:50,523 - INFO - Cluster 213: 9 points, max distance 2355.58
# 2025-07-16 13:32:50,525 - INFO - Cluster 214: 25 points, max distance 2470.02
# 2025-07-16 13:32:50,527 - INFO - Cluster 215: 28 points, max distance 2033.28
# 2025-07-16 13:32:50,529 - INFO - Cluster 216: 9 points, max distance 2552.98
# 2025-07-16 13:32:50,530 - INFO - Cluster 217: 16 points, max distance 2122.32
# 2025-07-16 13:32:50,532 - INFO - Cluster 218: 19 points, max distance 1923.13
# 2025-07-16 13:32:50,538 - INFO - Cluster 219: 45 points, max distance 2204.19
# 2025-07-16 13:32:50,540 - INFO - Cluster 220: 30 points, max distance 2426.02
# 2025-07-16 13:32:50,541 - INFO - Cluster 221: 11 points, max distance 2082.21
# 2025-07-16 13:32:50,544 - INFO - Cluster 222: 9 points, max distance 2229.81
# 2025-07-16 13:32:50,548 - INFO - Cluster 223: 54 points, max distance 3226.66
# 2025-07-16 13:32:50,549 - INFO - Cluster 224: 7 points, max distance 2111.72
# 2025-07-16 13:32:50,551 - INFO - Cluster 225: 57 points, max distance 2699.47
# 2025-07-16 13:32:50,555 - INFO - Cluster 226: 18 points, max distance 2784.66
# 2025-07-16 13:32:50,561 - INFO - Cluster 227: 160 points, max distance 1667.88
# 2025-07-16 13:32:50,564 - INFO - Cluster 228: 21 points, max distance 1848.50
# 2025-07-16 13:32:50,565 - INFO - Cluster 229: 7 points, max distance 2138.80
# 2025-07-16 13:32:50,566 - INFO - Cluster 230: 10 points, max distance 2381.26
# 2025-07-16 13:32:50,569 - INFO - Cluster 231: 13 points, max distance 2131.47
# 2025-07-16 13:32:50,571 - INFO - Cluster 232: 24 points, max distance 2220.71
# 2025-07-16 13:32:50,573 - INFO - Cluster 233: 16 points, max distance 2561.12
# 2025-07-16 13:32:50,574 - INFO - Cluster 234: 15 points, max distance 2438.30
# 2025-07-16 13:32:50,576 - INFO - Cluster 235: 9 points, max distance 2292.72
# 2025-07-16 13:32:50,577 - INFO - Cluster 236: 13 points, max distance 2406.24
# 2025-07-16 13:32:50,581 - INFO - Cluster 237: 25 points, max distance 2147.77
# 2025-07-16 13:32:50,583 - INFO - Cluster 238: 32 points, max distance 1706.46
# 2025-07-16 13:32:50,584 - INFO - Cluster 239: 24 points, max distance 2407.94
# 2025-07-16 13:32:50,588 - INFO - Cluster 240: 53 points, max distance 1870.13
# 2025-07-16 13:32:50,590 - INFO - Cluster 241: 19 points, max distance 2374.40
# 2025-07-16 13:32:50,593 - INFO - Cluster 242: 14 points, max distance 2395.04
# 2025-07-16 13:32:50,594 - INFO - Cluster 243: 15 points, max distance 2045.68
# 2025-07-16 13:32:50,596 - INFO - Cluster 244: 20 points, max distance 2098.99
# 2025-07-16 13:32:50,598 - INFO - Cluster 245: 18 points, max distance 2498.74
# 2025-07-16 13:32:50,599 - INFO - Cluster 246: 13 points, max distance 2338.60
# 2025-07-16 13:32:50,603 - INFO - Cluster 247: 14 points, max distance 2294.85
# 2025-07-16 13:32:50,606 - INFO - Cluster 248: 17 points, max distance 1953.35
# 2025-07-16 13:32:50,607 - INFO - Cluster 249: 13 points, max distance 1889.20
# 2025-07-16 13:32:50,609 - INFO - Cluster 250: 9 points, max distance 2061.81
# 2025-07-16 13:32:50,610 - INFO - Cluster 251: 11 points, max distance 2361.07
# 2025-07-16 13:32:50,612 - INFO - Cluster 252: 23 points, max distance 2015.36
# 2025-07-16 13:32:50,614 - INFO - Cluster 253: 7 points, max distance 2337.32
# 2025-07-16 13:32:50,616 - INFO - Cluster 254: 11 points, max distance 2088.89
# 2025-07-16 13:32:50,618 - INFO - Cluster 255: 19 points, max distance 2353.89
# 2025-07-16 13:32:50,623 - INFO - Cluster 256: 62 points, max distance 2393.81
# 2025-07-16 13:32:50,625 - INFO - Cluster 257: 27 points, max distance 2297.18
# 2025-07-16 13:32:50,627 - INFO - Cluster 258: 21 points, max distance 2530.91
# 2025-07-16 13:32:50,628 - INFO - Cluster 259: 14 points, max distance 2267.81
# 2025-07-16 13:32:50,630 - INFO - Cluster 260: 12 points, max distance 2531.23
# 2025-07-16 13:32:50,632 - INFO - Cluster 261: 29 points, max distance 2669.84
# 2025-07-16 13:32:50,634 - INFO - Cluster 262: 22 points, max distance 2682.80
# 2025-07-16 13:32:50,635 - INFO - Cluster 263: 13 points, max distance 2222.44
# 2025-07-16 13:32:50,637 - INFO - Cluster 264: 22 points, max distance 2208.27
# 2025-07-16 13:32:50,638 - INFO - Cluster 265: 18 points, max distance 2197.63
# 2025-07-16 13:32:50,640 - INFO - Cluster 266: 7 points, max distance 1906.76
# 2025-07-16 13:32:50,643 - INFO - Cluster 267: 13 points, max distance 2402.25
# 2025-07-16 13:32:50,645 - INFO - Cluster 268: 19 points, max distance 2519.72
# 2025-07-16 13:32:50,647 - INFO - Cluster 269: 30 points, max distance 2544.66
# 2025-07-16 13:32:50,648 - INFO - Cluster 270: 19 points, max distance 2155.17
# 2025-07-16 13:32:50,650 - INFO - Cluster 271: 9 points, max distance 2139.84
# 2025-07-16 13:32:50,652 - INFO - Cluster 272: 30 points, max distance 2025.60
# 2025-07-16 13:32:50,653 - INFO - Cluster 273: 14 points, max distance 2376.38
# 2025-07-16 13:32:50,656 - INFO - Cluster 274: 20 points, max distance 2596.65
# 2025-07-16 13:32:50,658 - INFO - Cluster 275: 21 points, max distance 1756.20
# 2025-07-16 13:32:50,659 - INFO - Cluster 276: 10 points, max distance 1920.40
# 2025-07-16 13:32:50,660 - INFO - Cluster 277: 11 points, max distance 2739.27
# 2025-07-16 13:32:50,662 - INFO - Cluster 278: 8 points, max distance 1780.98
# 2025-07-16 13:32:50,664 - INFO - Cluster 279: 24 points, max distance 2236.41
# 2025-07-16 13:32:50,667 - INFO - Cluster 280: 9 points, max distance 2102.95
# 2025-07-16 13:32:50,671 - INFO - Cluster 281: 11 points, max distance 2137.92
# 2025-07-16 13:32:50,674 - INFO - Cluster 282: 12 points, max distance 2068.50
# 2025-07-16 13:32:50,676 - INFO - Cluster 283: 18 points, max distance 2269.44
# 2025-07-16 13:32:50,678 - INFO - Cluster 284: 16 points, max distance 1940.00
# 2025-07-16 13:32:50,679 - INFO - Cluster 285: 15 points, max distance 2283.29
# 2025-07-16 13:32:50,682 - INFO - Cluster 286: 15 points, max distance 2168.77
# 2025-07-16 13:32:50,683 - INFO - Cluster 287: 21 points, max distance 2818.43
# 2025-07-16 13:32:50,686 - INFO - Cluster 288: 10 points, max distance 2142.46
# 2025-07-16 13:32:50,688 - INFO - Cluster 289: 10 points, max distance 2112.76
# 2025-07-16 13:32:50,689 - INFO - Cluster 290: 7 points, max distance 1764.41
# 2025-07-16 13:32:50,692 - INFO - Cluster 291: 35 points, max distance 2171.50
# 2025-07-16 13:32:50,693 - INFO - Cluster 292: 28 points, max distance 2232.51
# 2025-07-16 13:32:50,695 - INFO - Cluster 293: 16 points, max distance 2025.49
# 2025-07-16 13:32:50,696 - INFO - Cluster 294: 9 points, max distance 2456.75
# 2025-07-16 13:32:50,698 - INFO - Cluster 295: 5 points, max distance 2063.34
# 2025-07-16 13:32:50,700 - INFO - Cluster 296: 13 points, max distance 2241.12
# 2025-07-16 13:32:50,702 - INFO - Cluster 297: 17 points, max distance 2205.29
# 2025-07-16 13:32:50,703 - INFO - Cluster 298: 20 points, max distance 2059.83
# 2025-07-16 13:32:50,704 - INFO - Cluster 299: 7 points, max distance 1573.16
# 2025-07-16 13:32:50,708 - INFO - Cluster 300: 18 points, max distance 2272.30
# 2025-07-16 13:32:50,710 - INFO - Cluster 301: 18 points, max distance 2321.40
# 2025-07-16 13:32:50,712 - INFO - Cluster 302: 30 points, max distance 1971.05
# 2025-07-16 13:32:50,715 - INFO - Cluster 303: 13 points, max distance 1820.10
# 2025-07-16 13:32:50,717 - INFO - Cluster 304: 25 points, max distance 2133.82
# 2025-07-16 13:32:50,720 - INFO - Cluster 305: 11 points, max distance 1796.81
# 2025-07-16 13:32:50,722 - INFO - Cluster 306: 10 points, max distance 2347.21
# 2025-07-16 13:32:50,724 - INFO - Cluster 307: 18 points, max distance 2040.75
# 2025-07-16 13:32:50,725 - INFO - Cluster 308: 7 points, max distance 1519.74
# 2025-07-16 13:32:50,727 - INFO - Cluster 309: 21 points, max distance 2298.07
# 2025-07-16 13:32:50,729 - INFO - Cluster 310: 17 points, max distance 1788.36
# 2025-07-16 13:32:50,732 - INFO - Cluster 311: 30 points, max distance 1682.12
# 2025-07-16 13:32:50,734 - INFO - Cluster 312: 28 points, max distance 1904.15
# 2025-07-16 13:32:50,737 - INFO - Cluster 313: 19 points, max distance 2273.43
# 2025-07-16 13:32:50,739 - INFO - Cluster 314: 29 points, max distance 2038.95
# 2025-07-16 13:32:50,742 - INFO - Cluster 315: 16 points, max distance 2156.93
# 2025-07-16 13:32:50,743 - INFO - Cluster 316: 19 points, max distance 2101.79
# 2025-07-16 13:32:50,746 - INFO - Cluster 317: 15 points, max distance 2568.17
# 2025-07-16 13:32:50,748 - INFO - Cluster 318: 13 points, max distance 2254.81
# 2025-07-16 13:32:50,750 - INFO - Cluster 319: 9 points, max distance 2063.36
# 2025-07-16 13:32:50,753 - INFO - Cluster 320: 29 points, max distance 2479.42
# 2025-07-16 13:32:50,754 - INFO - Cluster 321: 5 points, max distance 1992.92
# 2025-07-16 13:32:50,756 - INFO - Cluster 322: 14 points, max distance 2396.14
# 2025-07-16 13:32:50,757 - INFO - Cluster 323: 17 points, max distance 2157.34
# 2025-07-16 13:32:50,761 - INFO - Cluster 324: 32 points, max distance 1895.86
# 2025-07-16 13:32:50,763 - INFO - Cluster 325: 9 points, max distance 2195.08
# 2025-07-16 13:32:50,766 - INFO - Cluster 326: 13 points, max distance 2681.77
# 2025-07-16 13:32:50,768 - INFO - Cluster 327: 18 points, max distance 2555.11
# 2025-07-16 13:32:50,769 - INFO - Cluster 328: 20 points, max distance 2206.64
# 2025-07-16 13:32:50,771 - INFO - Cluster 329: 10 points, max distance 2335.55
# 2025-07-16 13:32:50,773 - INFO - Cluster 330: 13 points, max distance 2392.00
# 2025-07-16 13:32:50,776 - INFO - Cluster 331: 25 points, max distance 2342.60
# 2025-07-16 13:32:50,779 - INFO - Cluster 332: 12 points, max distance 2140.79
# 2025-07-16 13:32:50,782 - INFO - Cluster 333: 40 points, max distance 2697.00
# 2025-07-16 13:32:50,784 - INFO - Cluster 334: 17 points, max distance 2198.89
# 2025-07-16 13:32:50,787 - INFO - Cluster 335: 18 points, max distance 2240.13
# 2025-07-16 13:32:50,789 - INFO - Cluster 336: 18 points, max distance 1912.24
# 2025-07-16 13:32:50,791 - INFO - Cluster 337: 10 points, max distance 2417.24
# 2025-07-16 13:32:50,792 - INFO - Cluster 338: 16 points, max distance 1930.45
# 2025-07-16 13:32:50,794 - INFO - Cluster 339: 7 points, max distance 2051.08
# 2025-07-16 13:32:50,795 - INFO - Cluster 340: 3 points, max distance 1748.19
# 2025-07-16 13:32:50,798 - INFO - Cluster 341: 11 points, max distance 2164.40
# 2025-07-16 13:32:50,800 - INFO - Cluster 342: 22 points, max distance 2156.56
# 2025-07-16 13:32:50,801 - INFO - Cluster 343: 12 points, max distance 1971.55
# 2025-07-16 13:32:50,803 - INFO - Cluster 344: 12 points, max distance 2189.11
# 2025-07-16 13:32:50,807 - INFO - Cluster 345: 22 points, max distance 2575.22
# 2025-07-16 13:32:50,808 - INFO - Cluster 346: 8 points, max distance 1800.45
# 2025-07-16 13:32:50,810 - INFO - Cluster 347: 8 points, max distance 1856.16
# 2025-07-16 13:32:50,811 - INFO - Cluster 348: 6 points, max distance 2301.73
# 2025-07-16 13:32:50,813 - INFO - Cluster 349: 13 points, max distance 2143.95
# 2025-07-16 13:32:50,815 - INFO - Cluster 350: 12 points, max distance 2140.55
# 2025-07-16 13:32:50,820 - INFO - Cluster 351: 39 points, max distance 2198.07
# 2025-07-16 13:32:50,821 - INFO - Cluster 352: 25 points, max distance 2303.80
# 2025-07-16 13:32:50,824 - INFO - Cluster 353: 29 points, max distance 2647.24
# 2025-07-16 13:32:50,825 - INFO - Cluster 354: 17 points, max distance 2377.52
# 2025-07-16 13:32:50,828 - INFO - Cluster 355: 23 points, max distance 2324.37
# 2025-07-16 13:32:50,829 - INFO - Cluster 356: 22 points, max distance 2401.58
# 2025-07-16 13:32:50,831 - INFO - Cluster 357: 34 points, max distance 1975.91
# 2025-07-16 13:32:50,835 - INFO - Cluster 358: 28 points, max distance 1820.78
# 2025-07-16 13:32:50,837 - INFO - Cluster 359: 7 points, max distance 2254.69
# 2025-07-16 13:32:50,840 - INFO - Cluster 360: 18 points, max distance 2458.08
# 2025-07-16 13:32:50,841 - INFO - Cluster 361: 5 points, max distance 1371.26
# 2025-07-16 13:32:50,842 - INFO - Cluster 362: 6 points, max distance 2340.27
# 2025-07-16 13:32:50,844 - INFO - Cluster 363: 10 points, max distance 2381.85
# 2025-07-16 13:32:50,847 - INFO - Cluster 364: 18 points, max distance 2416.92
# 2025-07-16 13:32:50,848 - INFO - Cluster 365: 14 points, max distance 2138.97
# 2025-07-16 13:32:50,850 - INFO - Cluster 366: 8 points, max distance 1737.75
# 2025-07-16 13:32:50,852 - INFO - Cluster 367: 43 points, max distance 2814.99
# 2025-07-16 13:32:50,855 - INFO - Cluster 368: 9 points, max distance 1748.05
# 2025-07-16 13:32:50,856 - INFO - Cluster 369: 11 points, max distance 1886.70
# 2025-07-16 13:32:50,857 - INFO - Cluster 370: 9 points, max distance 2000.21
# 2025-07-16 13:32:50,860 - INFO - Cluster 371: 13 points, max distance 1869.56
# 2025-07-16 13:32:50,861 - INFO - Cluster 372: 10 points, max distance 1915.21
# 2025-07-16 13:32:50,863 - INFO - Cluster 373: 8 points, max distance 1909.72
# 2025-07-16 13:32:50,864 - INFO - Cluster 374: 18 points, max distance 1851.15
# 2025-07-16 13:32:50,867 - INFO - Cluster 375: 14 points, max distance 1838.54
# 2025-07-16 13:32:50,869 - INFO - Cluster 376: 20 points, max distance 2048.41
# 2025-07-16 13:32:50,874 - INFO - Cluster 377: 9 points, max distance 1902.99
# 2025-07-16 13:32:50,875 - INFO - Cluster 378: 9 points, max distance 2250.01
# 2025-07-16 13:32:50,877 - INFO - Cluster 379: 9 points, max distance 2354.27
# 2025-07-16 13:32:50,878 - INFO - Cluster 380: 14 points, max distance 2744.26
# 2025-07-16 13:32:50,880 - INFO - Cluster 381: 22 points, max distance 2152.06
# 2025-07-16 13:32:50,882 - INFO - Cluster 382: 14 points, max distance 2016.48
# 2025-07-16 13:32:50,883 - INFO - Cluster 383: 29 points, max distance 2028.91
# 2025-07-16 13:32:50,885 - INFO - Cluster 384: 14 points, max distance 2004.57
# 2025-07-16 13:32:50,886 - INFO - Cluster 385: 26 points, max distance 2562.33
# 2025-07-16 13:32:50,888 - INFO - Cluster 386: 32 points, max distance 2522.80
# 2025-07-16 13:32:50,890 - INFO - Cluster 387: 13 points, max distance 1652.00
# 2025-07-16 13:32:50,893 - INFO - Cluster 388: 13 points, max distance 2174.52
# 2025-07-16 13:32:50,894 - INFO - Cluster 389: 13 points, max distance 2415.21
# 2025-07-16 13:32:50,895 - INFO - Cluster 390: 9 points, max distance 1545.98
# 2025-07-16 13:32:50,899 - INFO - Cluster 391: 14 points, max distance 2161.95
# 2025-07-16 13:32:50,901 - INFO - Cluster 392: 11 points, max distance 2263.08
# 2025-07-16 13:32:50,903 - INFO - Cluster 393: 8 points, max distance 2521.69
# 2025-07-16 13:32:50,906 - INFO - Cluster 394: 6 points, max distance 1984.51
# 2025-07-16 13:32:50,907 - INFO - Cluster 395: 26 points, max distance 2528.93
# 2025-07-16 13:32:50,909 - INFO - Cluster 396: 12 points, max distance 2222.36
# 2025-07-16 13:32:50,912 - INFO - Cluster 397: 6 points, max distance 1945.23
# 2025-07-16 13:32:50,914 - INFO - Cluster 398: 3 points, max distance 1531.76
# 2025-07-16 13:32:50,916 - INFO - Cluster 399: 22 points, max distance 2503.97
# 2025-07-16 13:32:51,002 - INFO - Cluster data saved to data/VisualPlaceCellData/VisualPlaceCellClusters/multimodal_gmm_400_LM8 in 94.80 seconds
